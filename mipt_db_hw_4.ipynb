# %% [markdown]
# # Выборка и агрегация данных в MongoDB
#
# ###Цель домашней работы
#
# Закрепить на практике основные приемы работы с СУБД MongoDB, включая выборку, сортировку, объединение, агрегацию данных и передачу результатов выборки в программу на Python в целях аналитики и дальнейшей обработки.

# %% [markdown]
# ### Формулировка задания
#
# В этом задании вам предстоит выполнить несколько запросов к базе данных для получения выборок по условиям, а также воспользоваться фреймворком агрегации MongoDB для построения конвейера обработки данных.
#
# Максимальное количество баллов за выполнение домашней работы: 10.

# %% [markdown]
# ##Что нужно использовать в работе над заданием
#
# I. MongoDB:
#
# 1. Зарегистрируйтесь в сервисе MongoDB Atlas: https://www.mongodb.com/atlas/database.
# 1. Создайте кластер уровня M0 (это бесплатно).
# 1. Добавьте в кластер тестовую базу данных `sample_mflix`, используя опцию Load Sample Dataset.
#
# В качестве альтернативы вы можете установить MongoDB на свой локальный компьютер и импортировать необходимые датасеты в свою СУБД, загрузив их по ссылке: https://github.com/neelabalan/mongodb-sample-dataset/tree/main/sample_mflix. Для этого подключитесь к своему серверу через Compass, создайте новую БД, создайте для каждого датасета коллекцию и щелкните «Add data» → «Import JSON or CSV file».
#
# II. MongoDB Compass — в качестве вспомогательного инструмента для конструирования запросов и агрегаций.
#
# III. Python и библиотека pymongo. Работа ведется в Jupyter Notebook или Google Colaboratory. Рекомендуется использовать версию Python 3.12.

# %% [markdown]
# ##Ожидаемые результаты
#
# Результаты работы необходимо оформить в виде ноутбука Jupyter. Можно загрузить файл в LMS либо поделиться ссылкой на Google Colaboratory.

# %% [markdown]
# ##Место где нужно выполнить задание

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.6.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.6.1)

# %%
# Импортируем библиотеки
import matplotlib.pyplot as plt
import pymongo

# %%
# Создаем клиента для подключения к MongoDB
client = pymongo.MongoClient("mongodb+srv://eduard_antonoff:Seven8ins@mipt.o3hk5at.mongodb.net/")

# Получаем список всех баз данных
client.list_database_names()
# Out:
# ['my_db',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %% [markdown]
# ### Упражнение 1. Запросы на выборку

# %% [markdown]
# Цель этого упражнения — закрепить навык выполнения запросов на выборку. Все запросы выполняются на базе `sample_mflix` с данными о кинофильмах.

# %% [markdown]
# #### Задача 1.1 — **1 балл**

# %% [markdown]
# Выведите из коллекции `theaters` документы о кинотеатрах в городе Florence, штат KY.
#
# Для справки:
#
# * Обратите внимание на то, что информация об адресе кинотеатров хранится во вложенных документах. Для доступа к полям вложенных документов следует использовать точку: `родительский_документ.вложенный_документ.поле`.
# * В случае затруднений с написанием логического условия обращайтесь к сопоставлению синтаксиса SQL и Mongo: https://www.mongodb.com/docs/manual/reference/sql-comparison/.
# * Если вы предпочитаете сперва выполнять запросы в Compass, из этого приложения можно выгружать код готового запроса на Python (кнопка с символом `</>`).

# %%
# Получаем доступ к базе данных 'sample_mflix'
db = client.sample_mflix

# %%
# Запрашиваем документы из коллекции 'theaters'
theaters_in_florence = db.theaters.find({
    "location.address.city": "Florence",
    "location.address.state": "KY"
})

# Преобразуем результат запроса в список и выводим его
list(theaters_in_florence)
# Out:
# [{'_id': ObjectId('59a47287cfa9a3a73e51e893'),
#   'theaterId': 161,
#   'location': {'address': {'street1': '100 Meijer Dr.',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.636383, 39.014843]}}},
#  {'_id': ObjectId('59a47287cfa9a3a73e51ea02'),
#   'theaterId': 2823,
#   'location': {'address': {'street1': '2823 Florence Mall',
#     'street2': '#2148',
#     'city': 'Florence',
#     'state': 'KY',
#     'zipcode': '41042'},
#    'geo': {'type': 'Point', 'coordinates': [-84.6499595, 38.9967246]}}}]

# %% [markdown]
# #### Задача 1.2 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `comments`, выведите _один_ комментарий (значение поля `text`) пользователя по имени Doreah.

# %%
# Ищем один документ в коллекции 'comments'
comment_doreah = db.comments.find_one({"name": "Doreah"})

# Выводим текст найденного комментария
print(comment_doreah["text"])
# Out:
# Porro explicabo cumque vitae sint quia quis. Consequuntur voluptatibus optio maxime ratione temporibus incidunt minus architecto.

# %% [markdown]
# #### Задача 1.3 — **1 балл**

# %% [markdown]
# Сделав запрос к коллекции `movies`, выведите количество документов, в которых в качестве первого жанра фильма (поле `genres`) указано значение «Horror».
#
# Для справки:
#
# 1. Обратите внимание, что поле `genres` представляет собой массив (индексация массивов начинается с нуля).
# 1. При работе в MongoDB Shell для подсчета количества документов в курсоре можно использовать метод `count()`, однако он был удален в последних версиях библиотеки pymongo. В случае затруднений с использованием функций Mongo можно использовать для подсчета документов средства Python.

# %%
# Считаем количество документов в коллекции 'movies'
cursor = db.movies.count_documents({"genres": "Horror"})

# Выводим количество найденных фильмов жанра Horror
print("Количество фильмов жанра Horror:", cursor)
# Out:
# Количество фильмов жанра Horror: 1470

# %% [markdown]
# #### Задача 1.4 — **2 балла**

# %% [markdown]
# Выведите из коллекции `movies` документы о фильмах, которые в качестве первого жанра определены как «Film-Noir» либо «Horror» и были выпущены в период с 1940 по 1949 гг. (включительно).

# %%
# Запрашиваем документы из коллекции 'movies'
query = {"genres": {"$in": ["Film-Noir", "Horror"]},
         "year": {"$gte": 1940, "$lte": 1949}}

movies = db.movies.find(query)

# Преобразуем результат запроса в список и выводим его
list(movies)
# Out:
# [{'_id': ObjectId('573a1393f29313caabcdbef6'),
#   'plot': "Dr. Sovac transplants the brain of a gangster into his professor friend's body to save his life, but there is a side effect that causes a dangerous split personality.",
#   'genres': ['Drama', 'Horror', 'Sci-Fi'],
#   'runtime': 70,
#   'rated': 'APPROVED',
#   'cast': ['Boris Karloff', 'Bela Lugosi', 'Stanley Ridges', 'Anne Nagel'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZmI5NzFlY2EtOTA5OS00MzYwLWE4MTAtMDI5NmJlZTYzNTJmXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Black Friday',
#   'fullplot': "When his friend Professor Kingsley is at deaths door, brain surgeon Dr. Sovac saves his life by means of an illegal operation that transplants part of injured gangster Red Cannon's brain. Unfortunately, the operation has a disastrous Jeckll and Hyde side effect and under certain conditions the persona of Cannon emerges. Sovac soon learns of the duel personality and of half a million dollars the gangster has hidden away. He attempts to find the money through the manipulation of his friend, an attempt that brings Kingsley closer to madness as he alternates between a meek professor of English and a brutal gangster out for murderous revenge on those who tried to kill him.",
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 4, 12, 0, 0),
#   'directors': ['Arthur Lubin'],
#   'writers': ['Curt Siodmak (screenplay)', 'Eric Taylor (screenplay)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-28 00:13:05.830000000',
#   'year': 1940,
#   'imdb': {'rating': 6.3, 'votes': 1121, 'id': 32258},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 711, 'meter': 47},
#    'dvd': datetime.datetime(1995, 8, 8, 0, 0),
#    'production': 'Passport',
#    'lastUpdated': datetime.datetime(2015, 8, 4, 20, 5, 37)}},
#  {'_id': ObjectId('573a1393f29313caabcdc0bb'),
#   'plot': 'The wife of a rubber plantation administrator shoots a man to death and claims it was self-defense, but a letter in her own hand may prove her undoing.',
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 95,
#   'rated': 'APPROVED',
#   'cast': ['Bette Davis',
#    'Herbert Marshall',
#    'James Stephenson',
#    'Frieda Inescort'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNGI1Mjk4ZDgtMDc5ZS00MGI4LWJmZDctNTZkNmQ0NGU0M2JlXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Letter',
#   'fullplot': "The wife of a rubber plantation administrator shoots a man to death and claims it was self-defense. Her poise, graciousness and stoicism impress nearly everyone who meets her. Her husband is certainly without doubt; so is the district officer; while her lawyer's doubts may be a natural skepticism. But this is Singapore and the resentful natives will have no compunction about undermining this accused murderess. A letter in her hand turns up and may prove her undoing.",
#   'languages': ['English'],
#   'released': datetime.datetime(1940, 11, 23, 0, 0),
#   'directors': ['William Wyler'],
#   'writers': ['W. Somerset Maugham (by)', 'Howard Koch (screen play)'],
#   'awards': {'wins': 9,
#    'nominations': 0,
#    'text': 'Nominated for 7 Oscars. Another 2 wins.'},
#   'lastupdated': '2015-09-14 11:50:17.477000000',
#   'year': 1940,
#   'imdb': {'rating': 7.7, 'votes': 7824, 'id': 32701},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 3598, 'meter': 83},
#    'dvd': datetime.datetime(2005, 1, 11, 0, 0),
#    'critic': {'rating': 8.6, 'numReviews': 9, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 23, 16, 22, 41),
#    'rotten': 0,
#    'production': 'MGM Home Entertainment',
#    'fresh': 9}},
#  {'_id': ObjectId('573a1393f29313caabcdc742'),
#   'plot': 'A practical man returns to his homeland, is attacked by a creature of folklore, and infected with a horrific disease his disciplined mind tells him can not possibly exist.',
#   'genres': ['Drama', 'Horror'],
#   'runtime': 70,
#   'rated': 'APPROVED',
#   'cast': ['Lon Chaney Jr.',
#    'Claude Rains',
#    'Warren William',
#    'Ralph Bellamy'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BODRmMDBjMTYtZmJiZi00Mzk3LWFhZDAtMDExNDFhMWQzNzEyXkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Wolf Man',
#   'fullplot': "Upon the death of his brother, Larry Talbot returns from America to his ancestral home in Wales. He visits a gypsy camp with village girl Jenny Williams, who is attacked by Bela, a gypsy who has turned into a werewolf. Larry kills the werewolf but is bitten during the fight. Bela's mother tells him that this will cause him to become a werewolf at each full moon. Larry confesses his plight to his unbelieving father, Sir John, who then joins the villagers in a hunt for the wolf. Transformed by the full moon, Larry heads for the forest and a fateful meeting with both Sir John and Gwen Conliffe.",
#   'languages': ['English'],
#   'released': datetime.datetime(1941, 12, 12, 0, 0),
#   'directors': ['George Waggner'],
#   'writers': ['Curt Siodmak (original screenplay)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-01 00:16:01.100000000',
#   'year': 1941,
#   'imdb': {'rating': 7.4, 'votes': 14875, 'id': 34398},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 10053, 'meter': 80},
#    'dvd': datetime.datetime(2001, 8, 28, 0, 0),
#    'critic': {'rating': 7.9, 'numReviews': 35, 'meter': 94},
#    'lastUpdated': datetime.datetime(2015, 9, 12, 18, 10, 25),
#    'consensus': 'A handsomely told tale with an affecting performance from Lon Chaney, Jr., The Wolf Man remains one of the classics of the Universal horror stable.',
#    'rotten': 2,
#    'production': 'Universal Pictures',
#    'fresh': 33}},
#  {'_id': ObjectId('573a1393f29313caabcdc814'),
#   'plot': "An American man marries a Serbian immigrant who fears that she will turn into the cat person of her homeland's fables if they are intimate together.",
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Simone Simon', 'Kent Smith', 'Tom Conway', 'Jane Randolph'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzI4YWY0NWQtNWI5YS00MGE4LWE4YTgtMzBmOWIwMzdiYTRiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Cat People',
#   'fullplot': 'Irena Dubrovna, a beautiful and mysterious Serbian-born fashion artist living in New York City, falls in love with and marries average-Joe American Oliver Reed. Their marriage suffers though, as Irena believes that she suffers from an ancient curse- whenever emotionally aroused, she will turn into a panther and kill. Oliver thinks that is absurd and childish, so he sends her to psychiatrist Dr. Judd to cure her. Easier said than done...',
#   'languages': ['English', 'Czech', 'Serbian'],
#   'released': datetime.datetime(1942, 12, 25, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['DeWitt Bodeen'],
#   'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'},
#   'lastupdated': '2015-08-21 00:53:54.453000000',
#   'year': 1942,
#   'imdb': {'rating': 7.4, 'votes': 11589, 'id': 34587},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 7115},
#    'critic': {'rating': 8.3, 'numReviews': 40, 'meter': 93},
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 3, 25),
#    'consensus': 'Influential noir director Jacques Tourneau infused this sexy, moody horror film with some sly commentary about the psychology and the taboos of desire.',
#    'rotten': 3,
#    'production': 'RKO Pictures',
#    'fresh': 37},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdcd6b'),
#   'plot': 'After the Nazi administrator of Czechoslovakia is shot, his assassin tries to elude the Gestapo and struggles with his impulse to give himself up as hostages are executed.',
#   'genres': ['Drama', 'Film-Noir', 'Thriller'],
#   'runtime': 134,
#   'rated': 'APPROVED',
#   'cast': ['Brian Donlevy', 'Walter Brennan', 'Anna Lee', 'Gene Lockhart'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTAzNjcyMTQyNTBeQTJeQWpwZ15BbWU4MDAwMTY2ODIx._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Hangmen Also Die!',
#   'fullplot': 'On May 27, 1942 the Nazi Reichsprotector of Bohemia/Moravia, the "Hangman" Reinhard Heydrich, died from the bullets of unidentified resistance fighters. Hangmen Also Die is the story of Heydrich\'s assassination in fictionalized form. It was Bertolt Brecht\'s only comparatively successful Hollywood project; the money he received allowed him to write "The Visions of Simone Marchand", "Schwyk in the Second World War" and his adaptation of Webster\'s "The Duchess of Malfi". Hanns Eisler won an Academy Award for his musical score.',
#   'languages': ['English', 'German'],
#   'released': datetime.datetime(1943, 4, 15, 0, 0),
#   'directors': ['Fritz Lang'],
#   'writers': ['Bertolt Brecht (adaptation)',
#    'Fritz Lang (adaptation)',
#    'John Wexley (screenplay)'],
#   'awards': {'wins': 4,
#    'nominations': 0,
#    'text': 'Nominated for 2 Oscars. Another 2 wins.'},
#   'lastupdated': '2015-09-04 00:41:47.757000000',
#   'year': 1943,
#   'imdb': {'rating': 7.5, 'votes': 2804, 'id': 35966},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 367, 'meter': 69},
#    'dvd': datetime.datetime(2000, 5, 9, 0, 0),
#    'critic': {'rating': 7.8, 'numReviews': 11, 'meter': 82},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 43, 9),
#    'rotten': 2,
#    'production': 'Cohen Media Group',
#    'fresh': 9}},
#  {'_id': ObjectId('573a1393f29313caabcdcd9d'),
#   'plot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis ...',
#   'genres': ['Horror'],
#   'runtime': 69,
#   'rated': 'APPROVED',
#   'cast': ['James Ellison', 'Frances Dee', 'Tom Conway', 'Edith Barrett'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZjQzMzliN2YtYTVhNC00Zjc4LThjMmYtMTE0ZGUzMWNmYzJlXkEyXkFqcGdeQXVyMTYxNjkxOQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'I Walked with a Zombie',
#   'fullplot': 'A young Canadian nurse (Betsy) comes to the West Indies to care for Jessica, the wife of a plantation manager (Paul Holland). Jessica seems to be suffering from a kind of mental paralysis as a result of fever. When she falls in love with Paul, Betsy determines to cure Jessica even if she needs to use a voodoo ceremony, to give Paul what she thinks he wants.',
#   'languages': ['English'],
#   'released': datetime.datetime(1943, 4, 30, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Curt Siodmak (screenplay)',
#    'Ardel Wray (screenplay)',
#    'Inez Wallace (original story)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-16 00:16:16.823000000',
#   'year': 1943,
#   'imdb': {'rating': 7.3, 'votes': 6893, 'id': 36027},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 4884, 'meter': 75},
#    'dvd': datetime.datetime(2005, 10, 4, 0, 0),
#    'critic': {'rating': 8.1, 'numReviews': 26, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 16, 16),
#    'consensus': "Evocative direction by Jacques Tourneur collides with the low-rent production values of exploitateer Val Lewton in I Walked with a Zombie, a sultry sleeper that's simultaneously smarmy, eloquent and fascinating.",
#    'rotten': 2,
#    'production': 'Warner Home Video',
#    'fresh': 24}},
#  {'_id': ObjectId('573a1393f29313caabcdcdf5'),
#   'plot': 'A seemingly tame leopard used for a publicity stunt escapes and kills a young girl, spreading panic throughout a sleepy new Mexico town.',
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 66,
#   'rated': 'APPROVED',
#   'cast': ["Dennis O'Keefe", 'Margo', 'Jean Brooks', 'Isabel Jewell'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYmU4ZDI5NGMtYzM1OC00YTQ3LWI1NTEtNGM0Mzc0ZDA5NzI4XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Leopard Man',
#   'fullplot': 'At the encouragement of her manager, a nightclub performer in New Mexico (Kiki Walker) takes a leashed leopard into the club as a publicity gimmick. But her rival, angered by the attempt to upstage, scares the animal and it bolts. In the days that follow, people are mauled and the countryside is combed for the loose creature. But Kiki and her manager begin to wonder if maybe the leopard is not responsible for the killings.',
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1943, 5, 8, 0, 0),
#   'directors': ['Jacques Tourneur'],
#   'writers': ['Ardel Wray (screenplay)',
#    'Edward Dein (additional dialogue)',
#    'Cornell Woolrich (novel)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-05 00:17:53.897000000',
#   'year': 1943,
#   'imdb': {'rating': 6.9, 'votes': 2889, 'id': 36104},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 1375, 'meter': 67},
#    'fresh': 15,
#    'critic': {'rating': 7.4, 'numReviews': 17, 'meter': 88},
#    'rotten': 2,
#    'lastUpdated': datetime.datetime(2015, 8, 27, 18, 6, 2)}},
#  {'_id': ObjectId('573a1393f29313caabcdce88'),
#   'plot': 'This is the story of a disfigured violinist who haunts the Paris Opera House',
#   'genres': ['Drama', 'Horror', 'Music'],
#   'runtime': 92,
#   'rated': 'APPROVED',
#   'cast': ['Nelson Eddy', 'Susanna Foster', 'Claude Rains', 'Edgar Barrier'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjM5MDU5MDU2NV5BMl5BanBnXkFtZTgwMTY2NzcyMjE@._V1._CR7.883331298828125,10.533340454101562,323,484_SX178_AL_.jpg',
#   'title': 'Phantom of the Opera',
#   'fullplot': 'Pit violinist Claudin hopelessly loves rising operatic soprano Christine Dubois (as do baritone Anatole and police inspector Raoul) and secretly aids her career. But Claudin loses both his touch and his job, murders a rascally music publisher in a fit of madness, and has his face etched with acid. Soon, mysterious crimes plague the Paris Opera House, blamed on a legendary "phantom" whom none can find in the mazes and catacombs. But both of Christine\'s lovers have plans to ferret him out.',
#   'languages': ['English'],
#   'released': datetime.datetime(1943, 8, 27, 0, 0),
#   'directors': ['Arthur Lubin'],
#   'writers': ['Eric Taylor (screenplay)',
#    'Samuel Hoffenstein (screenplay)',
#    'John Jacoby (adaptation)',
#    'Gaston Leroux (novel)'],
#   'awards': {'wins': 0,
#    'nominations': 4,
#    'text': 'Won 2 Oscars. Another 2 nominations.'},
#   'lastupdated': '2015-08-07 00:00:51.897000000',
#   'year': 1943,
#   'imdb': {'rating': 6.5, 'votes': 4011, 'id': 36261},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 34686, 'meter': 78},
#    'dvd': datetime.datetime(2005, 4, 12, 0, 0),
#    'critic': {'rating': 7.4, 'numReviews': 19, 'meter': 74},
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 41, 35),
#    'rotten': 5,
#    'production': 'MCA Universal Home Video',
#    'fresh': 14}},
#  {'_id': ObjectId('573a1393f29313caabcdceee'),
#   'plot': "A woman in search of her missing sister uncovers a Satanic cult in New York's Greenwich Village, and finds that they may have something to do with her sibling's random disappearance.",
#   'genres': ['Drama', 'Horror', 'Mystery'],
#   'runtime': 71,
#   'rated': 'APPROVED',
#   'cast': ['Tom Conway', 'Jean Brooks', 'Isabel Jewell', 'Kim Hunter'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzFjYTg1YTgtMTUwZi00ZTQxLWJjOWEtMzI5MTVkNjQ1ZDllXkEyXkFqcGdeQXVyMTAwMzUyOTc@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Seventh Victim',
#   'fullplot': "When her older sister Jacqueline disappears, Mary Gibson is forced to leave her private school and decides to travel to New York City to look for her. A bit naive and out of her depth, she is not quite sure how to go about finding her. Eventually she meets Gregory Ward, her sister's husband and a mysterious psychiatrist, Dr. Louis Judd who claims to know of Jacqueline's whereabouts. What she doesn't realize is that her sister became involved with devil worshipers who now want to eliminate her for having revealed their existence.",
#   'languages': ['English', 'Italian', 'Latin', 'French'],
#   'released': datetime.datetime(1943, 8, 21, 0, 0),
#   'directors': ['Mark Robson'],
#   'writers': ["Charles O'Neal", 'DeWitt Bodeen'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-07 00:00:56.380000000',
#   'year': 1943,
#   'imdb': {'rating': 7.0, 'votes': 3385, 'id': 36341},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 1302, 'meter': 65},
#    'dvd': datetime.datetime(2005, 10, 4, 0, 0),
#    'critic': {'rating': 7.5, 'numReviews': 13, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 3, 27),
#    'rotten': 1,
#    'production': 'RKO Radio Pictures',
#    'fresh': 12},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdd05d'),
#   'plot': 'This mostly unrelated sequel to Cat People (1942) has Amy, the young daughter of Oliver and Alice Reed. Amy is a very imaginative child who has trouble differentiating fantasy from reality,...',
#   'genres': ['Drama', 'Film-Noir'],
#   'runtime': 70,
#   'rated': 'APPROVED',
#   'cast': ['Simone Simon', 'Kent Smith', 'Jane Randolph', 'Ann Carter'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjkzMThjYzktMzhmOS00Nzk3LWIzYzAtYWJhMzhlOGEyM2UyXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Curse of the Cat People',
#   'fullplot': "This mostly unrelated sequel to Cat People (1942) has Amy, the young daughter of Oliver and Alice Reed. Amy is a very imaginative child who has trouble differentiating fantasy from reality, and has no friends her own age as a result. She makes an imaginary friend though, her father's dead first wife Irena. At about the same time, she befriends Julia Farren, an aging reclusive actress who is alienated from her own daughter Barbara.",
#   'languages': ['English'],
#   'released': datetime.datetime(1944, 10, 14, 0, 0),
#   'directors': ['Gunther von Fritsch', 'Robert Wise'],
#   'writers': ['DeWitt Bodeen (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-08-03 00:02:23.490000000',
#   'year': 1944,
#   'imdb': {'rating': 7.0, 'votes': 3686, 'id': 36733},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.4, 'numReviews': 3443, 'meter': 67},
#    'dvd': datetime.datetime(2005, 10, 4, 0, 0),
#    'critic': {'rating': 7.2, 'numReviews': 26, 'meter': 88},
#    'lastUpdated': datetime.datetime(2015, 8, 14, 18, 55, 44),
#    'consensus': 'Foregoing the horror thrills of its predecessor in favor of childhood fantasy, Curse of the Cat People is a touching and psychologically complex family film couched in a ghost story.',
#    'rotten': 3,
#    'production': 'WARNER BROTHERS PICTURES',
#    'fresh': 23},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdd0ae'),
#   'plot': "An insurance representative lets himself be talked into a murder/insurance fraud scheme that arouses an insurance investigator's suspicions.",
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 107,
#   'rated': 'PASSED',
#   'cast': ['Fred MacMurray',
#    'Barbara Stanwyck',
#    'Edward G. Robinson',
#    'Porter Hall'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BOGZiZjFiMWItN2NkZC00MjEwLTk4YzEtNTMwOTlmOGM3ZGJkXkEyXkFqcGdeQXVyMzAxNjg3MjQ@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Double Indemnity',
#   'fullplot': "In 1938, Walter Neff, an experienced salesman of the Pacific All Risk Insurance Co., meets the seductive wife of one of his clients, Phyllis Dietrichson, and they have an affair. Phyllis proposes to kill her husband to receive the proceeds of an accident insurance policy and Walter devises a scheme to receive twice the amount based on a double indemnity clause. When Mr. Dietrichson is found dead on a train-track, the police accept the determination of accidental death. However, the insurance analyst and Walter's best friend Barton Keyes does not buy the story and suspects that Phyllis has murdered her husband with the help of another man.",
#   'languages': ['English'],
#   'released': datetime.datetime(1944, 4, 24, 0, 0),
#   'directors': ['Billy Wilder'],
#   'writers': ['Billy Wilder (screenplay)',
#    'Raymond Chandler (screenplay)',
#    'James M. Cain (from the novel by)'],
#   'awards': {'wins': 11,
#    'nominations': 0,
#    'text': 'Nominated for 7 Oscars. Another 4 wins.'},
#   'lastupdated': '2015-09-16 13:02:19.503000000',
#   'year': 1944,
#   'imdb': {'rating': 8.4, 'votes': 88089, 'id': 36775},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.2, 'numReviews': 34925, 'meter': 95},
#    'dvd': datetime.datetime(2000, 10, 10, 0, 0),
#    'critic': {'rating': 9.0, 'numReviews': 54, 'meter': 96},
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 26, 30),
#    'consensus': "A dark, tautly constructed adaptation of James M. Cain's novel -- penned by Billy Wilder and Raymond Chandler -- Double Indemnity continues to set the standard for the best in Hollywood film noir.",
#    'rotten': 2,
#    'production': 'Paramount Pictures',
#    'fresh': 52}},
#  {'_id': ObjectId('573a1393f29313caabcdd170'),
#   'plot': 'A police detective falls in love with the woman whose murder he is investigating.',
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 88,
#   'rated': 'APPROVED',
#   'cast': ['Gene Tierney', 'Dana Andrews', 'Clifton Webb', 'Vincent Price'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYjkxOGM5OTktNTRmZi00MjhlLWE2MDktNzY3NjY3NmRjNDUyXkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Laura',
#   'fullplot': 'Detective Mark McPherson investigates the killing of Laura, found dead on her apartment floor before the movie starts. McPherson builds a mental picture of the dead girl from the suspects whom he interviews. He is helped by the striking painting of the late lamented Laura hanging on her apartment wall. But who would have wanted to kill a girl with whom every man she met seemed to fall in love? To make matters worse, McPherson finds himself falling under her spell too. Then one night, halfway through his investigations, something seriously bizarre happens to make him re-think the whole case.',
#   'languages': ['English'],
#   'released': datetime.datetime(1944, 11, 1, 0, 0),
#   'directors': ['Otto Preminger'],
#   'writers': ['Vera Caspary (novel)',
#    'Jay Dratler (screen play)',
#    'Samuel Hoffenstein (screen play)',
#    'Elizabeth Reinhardt (screen play)'],
#   'awards': {'wins': 2,
#    'nominations': 4,
#    'text': 'Won 1 Oscar. Another 1 win & 4 nominations.'},
#   'lastupdated': '2015-09-13 00:44:42.360000000',
#   'year': 1944,
#   'imdb': {'rating': 8.1, 'votes': 28491, 'id': 37008},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 9675, 'meter': 91},
#    'dvd': datetime.datetime(2005, 3, 15, 0, 0),
#    'critic': {'rating': 8.7, 'numReviews': 58, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 8, 5),
#    'consensus': 'A psychologically complex portrait of obsession, Laura is also a deliciously well-crafted murder mystery.',
#    'rotten': 0,
#    'production': '20th Century Fox',
#    'fresh': 58},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdd1ec'),
#   'plot': "After being hired to find an ex-con's former girlfriend, Philip Marlowe is drawn into a deeply complex web of mystery and deceit.",
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 95,
#   'rated': 'APPROVED',
#   'cast': ['Dick Powell', 'Claire Trevor', 'Anne Shirley', 'Otto Kruger'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BY2YyNWVhNzYtMjNkNS00YTNlLTlkYjYtMDVmMWExNTAxNGFlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Murder, My Sweet',
#   'fullplot': "This adaptation of the Raymond Chandler novel 'Farewell, My Lovely', renamed for the American market to prevent filmgoers mistaking it for a musical (for which Powell was already famous) has private eye Philip Marlowe hired by Moose Malloy, a petty crook just out of prison after a seven year stretch, to look for his former girlfriend, Velma, who has not been seen for the last six years. The case is tougher than Marlowe expected as his initially promising enquiries lead to a complex web of deceit involving bribery, perjury and theft, and where no one's motivation is obvious, least of all Marlowe's.",
#   'languages': ['English'],
#   'released': datetime.datetime(1944, 12, 9, 0, 0),
#   'directors': ['Edward Dmytryk'],
#   'writers': ['John Paxton (screenplay)', 'Raymond Chandler (novel)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-21 00:02:58.720000000',
#   'year': 1944,
#   'imdb': {'rating': 7.7, 'votes': 7897, 'id': 37101},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 3685, 'meter': 87},
#    'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#    'critic': {'rating': 7.7, 'numReviews': 14, 'meter': 93},
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 23, 7),
#    'rotten': 1,
#    'production': 'Warner Home Video',
#    'fresh': 13},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdd38c'),
#   'plot': 'A ruthless doctor and his young prize student find themselves continually harassed by their murderous supplier of illegal cadavers.',
#   'genres': ['Horror', 'Thriller'],
#   'runtime': 77,
#   'rated': 'APPROVED',
#   'title': 'The Body Snatcher',
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNzNmOTE0YTktZGZmYS00N2RhLWI5NTgtYTAyZjZhYWExMmRmXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['USA'],
#   'fullplot': "In Edinburgh in 1831, Dr. Wolfe MacFarlane runs a medical school where Donald Fettes is a student. Fettes is interested in helping a young girl who has lost the use of her legs. He is certain that MacFarlane's surgical skills could be put to great use but he is reluctant to do so. The good Dr. MacFarlane has a secret that soon becomes all too obvious to young Fettes, who has only recently been promoted as his assistant: he has been paying a local cabbie, John Gray, to supply him with dead bodies for anatomical research. Gray constantly harasses MacFarlane and clearly has a hold over him dating to a famous trial many years before where Gray refused to identify the man for whom he was robbing graves. Fettes isn't aware of any of this but soon realizes exactly how Gray obtains the bodies they use in their anatomy classes.",
#   'languages': ['English'],
#   'cast': ['Boris Karloff', 'Bela Lugosi', 'Henry Daniell', 'Edith Atwater'],
#   'directors': ['Robert Wise'],
#   'writers': ['Robert Louis Stevenson (short story)',
#    'Philip MacDonald (written for the screen by)',
#    'Val Lewton (written for the screen by)'],
#   'awards': {'wins': 0, 'nominations': 3, 'text': '3 nominations.'},
#   'lastupdated': '2015-08-16 01:24:24.840000000',
#   'year': 1945,
#   'imdb': {'rating': 7.4, 'votes': 5509, 'id': 37549},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 3664, 'meter': 75},
#    'critic': {'rating': 6.8, 'numReviews': 16, 'meter': 81},
#    'lastUpdated': datetime.datetime(2015, 8, 21, 19, 11, 47),
#    'rotten': 3,
#    'production': 'RKO Pictures',
#    'fresh': 13}},
#  {'_id': ObjectId('573a1393f29313caabcdd3e5'),
#   'plot': 'Chance events trap hitch-hiker Al Roberts in a tightening net of film noir trouble.',
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 67,
#   'rated': 'APPROVED',
#   'cast': ['Tom Neal', 'Ann Savage', 'Claudia Drake', 'Edmund MacDonald'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTVhNTU2YzMtOTVjNy00YzhhLTk5OWItMjU4ZGMyNDQ4ZDIwXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Detour',
#   'fullplot': "In flashback, New York nightclub pianist Al Roberts hitchhikes to Hollywood to join his girl Sue. On a rainy night, the sleazy gambler he's riding with mysteriously dies; afraid of the police, Roberts takes the man's identity. But thanks to a blackmailing dame, Roberts' every move plunges him deeper into trouble...",
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 11, 7, 0, 0),
#   'directors': ['Edgar G. Ulmer'],
#   'writers': ['Martin Goldsmith (screenplay)',
#    'Martin Goldsmith (original story)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-17 03:00:03.433000000',
#   'year': 1945,
#   'imdb': {'rating': 7.5, 'votes': 9254, 'id': 37638},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://filmchestmediagroup.com/',
#    'viewer': {'rating': 3.7, 'numReviews': 5229, 'meter': 78},
#    'dvd': datetime.datetime(2000, 9, 26, 0, 0),
#    'critic': {'rating': 8.2, 'numReviews': 19, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 1, 18, 1, 56),
#    'rotten': 0,
#    'production': 'Film Chest',
#    'fresh': 19},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdd3ed'),
#   'plot': 'An architect senses impending doom as his half-remembered recurring dream turns into reality. The guests at the country house encourage him to stay as they take turns telling supernatural tales.',
#   'genres': ['Horror'],
#   'runtime': 77,
#   'rated': 'APPROVED',
#   'cast': ['Mervyn Johns', 'Roland Culver', 'Mary Merrall', 'Googie Withers'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTY2OTJjZjgtMzExMy00MWJlLTg2N2ItM2NhMDQxNTNkNjFhXkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Dead of Night',
#   'fullplot': "Architect Walter Craig, seeking the possibility of some work at a country farmhouse, soon finds himself once again stuck in his recurring nightmare. Dreading the end of the dream that he knows is coming, he must first listen to all the assembled guests' own bizarre tales.",
#   'languages': ['English', 'French'],
#   'released': datetime.datetime(1945, 10, 15, 0, 0),
#   'directors': ['Alberto Cavalcanti',
#    'Charles Crichton',
#    'Basil Dearden',
#    'Robert Hamer'],
#   'writers': ['H.G. Wells (original story)',
#    'E.F. Benson (original story)',
#    'John Baines (original story)',
#    'Angus MacPhail (original story)',
#    'John Baines (screenplay)',
#    'Angus MacPhail (screenplay)',
#    'T.E.B. Clarke (additional dialogue)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-09-15 04:38:12.500000000',
#   'year': 1945,
#   'imdb': {'rating': 7.7, 'votes': 7116, 'id': 37635},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 3194, 'meter': 88},
#    'dvd': datetime.datetime(2009, 1, 27, 0, 0),
#    'critic': {'rating': 8.0, 'numReviews': 27, 'meter': 96},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 40, 43),
#    'consensus': 'With four accomplished directors contributing, Dead of Night is a classic horror anthology that remains highly influential.',
#    'rotten': 1,
#    'production': 'Universal Pictures',
#    'fresh': 26}},
#  {'_id': ObjectId('573a1393f29313caabcdd481'),
#   'plot': 'Count Dracula and the Wolf Man seek a cure for their afflictions; a hunchbacked woman, a mad scientist and the Frankenstein monster have their own troubles.',
#   'genres': ['Fantasy', 'Horror', 'Sci-Fi'],
#   'runtime': 67,
#   'rated': 'APPROVED',
#   'cast': ['Lon Chaney Jr.',
#    'John Carradine',
#    "Martha O'Driscoll",
#    'Lionel Atwill'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BY2UwMDljODktMTRhMS00MjEwLWJmMmQtODQzMWNmMzllZWNlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'House of Dracula',
#   'fullplot': "Dracula arrives at Dr. Edelman's office asking for a cure to his vampirism. However, this is a ruse by Dracula to get near Dr. Edelman's beautiful female assistant and turn her into a vampire. Meanwhile, a sincere Lawrence Talbot, AKA the Wolfman, arrives seeking a cure for his lycanthropy. When Dr. Edelman's first attempt fails, Talbot tries to commit suicide by jumping off a cliff, but instead finds a network of underground caves where Frankensteins Monster is in stasis. Chaos ensues as the three monsters fight for dominance of each other.",
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 12, 7, 0, 0),
#   'directors': ['Erle C. Kenton'],
#   'writers': ['Edward T. Lowe Jr. (original screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-09-12 00:01:05.017000000',
#   'year': 1945,
#   'imdb': {'rating': 5.8, 'votes': 2957, 'id': 37793},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.0, 'numReviews': 4896, 'meter': 29},
#    'dvd': datetime.datetime(1993, 9, 1, 0, 0),
#    'critic': {'rating': 5.1, 'numReviews': 8, 'meter': 50},
#    'lastUpdated': datetime.datetime(2015, 8, 10, 19, 43, 7),
#    'rotten': 4,
#    'production': 'Passport',
#    'fresh': 4}},
#  {'_id': ObjectId('573a1393f29313caabcdd482'),
#   'plot': 'Bill Dietrich becomes a double agent for the FBI in a Nazi spy ring.',
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 88,
#   'rated': 'APPROVED',
#   'cast': ['William Eythe', 'Lloyd Nolan', 'Signe Hasso', 'Gene Lockhart'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZTRlNDI2MjUtNzdmOS00NTViLTlhM2MtMmNjZmUxZmEzZmU2XkEyXkFqcGdeQXVyMjQwMDg0Ng@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The House on 92nd Street',
#   'fullplot': 'Preface: a stentorian narrator tells us that the USA was flooded with Nazi spies in 1939-41. One such tries to recruit college grad Bill Dietrich, who becomes a double agent for the FBI. While Bill trains in Hamburg, a street-accident victim proves to have been spying on atom-bomb secrets; conveniently, Dietrich is assigned to the New York spy ring stealing these secrets. Can he track down the mysterious "Christopher" before his ruthless associates unmask and kill him?',
#   'languages': ['English', 'German'],
#   'released': datetime.datetime(1945, 9, 10, 0, 0),
#   'directors': ['Henry Hathaway'],
#   'writers': ['Barrè Lyndon (screenplay)',
#    'Charles G. Booth (screenplay)',
#    'John Monks Jr. (screenplay)',
#    'Charles G. Booth (story)'],
#   'awards': {'wins': 2,
#    'nominations': 0,
#    'text': 'Won 1 Oscar. Another 1 win.'},
#   'lastupdated': '2015-08-26 00:05:21.620000000',
#   'year': 1945,
#   'imdb': {'rating': 6.8, 'votes': 2010, 'id': 37795},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 1181, 'meter': 50},
#    'dvd': datetime.datetime(2005, 9, 6, 0, 0),
#    'critic': {'rating': 6.6, 'numReviews': 5, 'meter': 60},
#    'lastUpdated': datetime.datetime(2015, 8, 23, 18, 40, 25),
#    'rotten': 2,
#    'production': 'Twentieth Century Fox',
#    'fresh': 3}},
#  {'_id': ObjectId('573a1393f29313caabcdd49b'),
#   'plot': "On a Greek island during the 1912 war, several people are trapped by quarantine for the plague. If that isn't enough worry, one of the people, a superstitious old peasant woman, suspects ...",
#   'genres': ['Drama', 'Film-Noir', 'Horror'],
#   'runtime': 71,
#   'rated': 'APPROVED',
#   'cast': ['Boris Karloff', 'Ellen Drew', 'Marc Cramer', 'Katherine Emery'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDQyOGJiZTctZTc4My00NTExLWFlZjEtMTdhNjY2Zjg2NjRlXkEyXkFqcGdeQXVyMTE2NzA0Ng@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Isle of the Dead',
#   'fullplot': "On a Greek island during the 1912 war, several people are trapped by quarantine for the plague. If that isn't enough worry, one of the people, a superstitious old peasant woman, suspects one young girl of being a vampiric kind of demon called a vorvolaka.",
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 9, 1, 0, 0),
#   'directors': ['Mark Robson'],
#   'writers': ['Ardel Wray'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-09-17 04:42:25.897000000',
#   'year': 1945,
#   'imdb': {'rating': 6.6, 'votes': 2642, 'id': 37820},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 1759, 'meter': 49},
#    'dvd': datetime.datetime(2006, 10, 31, 0, 0),
#    'critic': {'rating': 6.3, 'numReviews': 14, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 8, 23, 18, 45, 25),
#    'rotten': 2,
#    'fresh': 12}},
#  {'_id': ObjectId('573a1393f29313caabcdd4c8'),
#   'plot': 'A writer meets a young socialite on board a train. The two fall in love and are married soon after, but her obsessive love for him threatens to be the undoing of both them and everyone else around them.',
#   'genres': ['Drama', 'Film-Noir', 'Thriller'],
#   'runtime': 110,
#   'rated': 'APPROVED',
#   'cast': ['Gene Tierney', 'Cornel Wilde', 'Jeanne Crain', 'Vincent Price'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYjc0Nzc4OGQtNzIzZS00OWJiLWE3NjktMjFkMzY3ZTdlZTE1L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Leave Her to Heaven',
#   'fullplot': "Novelist Richard Harland and socialite Ellen Berent meet on a train to New Mexico. They are immediately attracted to each other, soon fall in love and decide to get married, about which everyone they know is happy except Ellen's fiancè back home, politician Russell Quinton. However, Richard and Ellen's love for each other is different than that of the other as Ellen demonstrates in the manner which she tells everyone of their impending marriage. Ellen's love for Richard is an obsessive, possessive one, much like the love she had for her now deceased father, who Richard physically resembles. Ellen wants Richard all to herself and resents anyone who even remotely takes a place in his life and heart, even if his love for that person is not a romantic one. These people include most specifically Richard's physically disabled teen-aged brother Danny Harland, Ellen's own adopted sister Ruth Berent, and a young man neither has gotten a chance to really know yet. After time, Richard learns to what extent Ellen will go to get what she wants, she who always wins.",
#   'languages': ['English'],
#   'released': datetime.datetime(1945, 12, 20, 0, 0),
#   'directors': ['John M. Stahl'],
#   'writers': ['Jo Swerling (screenplay)', 'Ben Ames Williams (novel)'],
#   'awards': {'wins': 0,
#    'nominations': 5,
#    'text': 'Won 1 Oscar. Another 4 nominations.'},
#   'lastupdated': '2015-09-17 04:44:08.367000000',
#   'year': 1945,
#   'imdb': {'rating': 7.8, 'votes': 7165, 'id': 37865},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 3269, 'meter': 86},
#    'dvd': datetime.datetime(2005, 2, 22, 0, 0),
#    'critic': {'rating': 8.2, 'numReviews': 19, 'meter': 95},
#    'lastUpdated': datetime.datetime(2015, 8, 16, 19, 20, 53),
#    'rotten': 1,
#    'production': '20th Century Fox Film Corporation',
#    'fresh': 18}},
#  {'_id': ObjectId('573a1393f29313caabcdd6b0'),
#   'plot': "Nell Bowen, the spirited protege of rich Lord Mortimer, becomes interested in the conditions of notorious St. Mary's of Bethlehem Asylum (Bedlam). Encouraged by the Quaker Hannay, she tries...",
#   'genres': ['Drama', 'Horror', 'Thriller'],
#   'runtime': 79,
#   'rated': 'APPROVED',
#   'cast': ['Boris Karloff', 'Anna Lee', 'Billy House', 'Richard Fraser'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BM2E2ZTEzZmMtNjliOS00MTFiLWIxZWUtNTNkODJmOTA0Mjc1XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Bedlam',
#   'fullplot': "Nell Bowen, the spirited protege of rich Lord Mortimer, becomes interested in the conditions of notorious St. Mary's of Bethlehem Asylum (Bedlam). Encouraged by the Quaker Hannay, she tries to bring support to reforming Bedlam, but the cruel Master Sims who runs it has her committed there. The inmates, however, have the last say.",
#   'languages': ['English'],
#   'released': datetime.datetime(1946, 5, 10, 0, 0),
#   'directors': ['Mark Robson'],
#   'writers': ['William Hogarth (suggested by The William Hogarth painting Bedlam Plate #8 "The Rake\'s Progress")',
#    'Val Lewton (screenplay)',
#    'Mark Robson (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-09-02 00:26:32.053000000',
#   'year': 1946,
#   'imdb': {'rating': 6.9, 'votes': 2326, 'id': 38343},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 1645, 'meter': 54},
#    'fresh': 14,
#    'critic': {'rating': 6.5, 'numReviews': 16, 'meter': 88},
#    'rotten': 2,
#    'lastUpdated': datetime.datetime(2015, 6, 21, 18, 10, 14)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcdd6b2'),
#   'plot': "Private detective Philip Marlowe is hired by a rich family. Before the complex case is over, he's seen murder, blackmail, and what might be love.",
#   'genres': ['Crime', 'Film-Noir', 'Mystery'],
#   'runtime': 114,
#   'rated': 'APPROVED',
#   'cast': ['Humphrey Bogart',
#    'Lauren Bacall',
#    'John Ridgely',
#    'Martha Vickers'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjdiM2IyZmQtODJiYy00NDNkLTllYmItMmFjMDNiYTQyOGVkXkEyXkFqcGdeQXVyNDY2MTk1ODk@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Big Sleep',
#   'fullplot': "Private detective Philip Marlowe is hired by old General Sternwood to stop a blackmail attempt concerning his youngest daughter Carmen. Marlowe tails the blackmailer Geiger to his house at Laverne Terrace. Suddenly he hears a shot and sees some men rushing out to their cars. He breaks into the house, and finds Carmel drugged in a chair, with Geiger's dead body at her feet. An empty camera proves that a photo has been taken of her and the corpse, probably intended for further blackmailing. A series of clues lead Marlowe to various persons involved in gambling. Wherever he finds them, he also finds Sternwood's oldest daughter, Vivian Rutledge, a divorced beauty. She and Marlowe fall in love with each other, although she continues double-crossing him. When Marlowe's investigations lead him to the casino owner Eddie Mars, the situation starts becoming very dangerous. Everyone, including the district attorney, advises Marlowe to stop the investigation, but he is stubborn. Eddie Mars has a lot of henchmen, who do the dirty jobs for him, including murder. But Marlowe decides to set up a trap for Mars himself.",
#   'languages': ['English'],
#   'released': datetime.datetime(1946, 8, 31, 0, 0),
#   'directors': ['Howard Hawks'],
#   'writers': ['William Faulkner (screen play)',
#    'Leigh Brackett (screen play)',
#    'Jules Furthman (screen play)',
#    'Raymond Chandler (from the novel by)'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-06 00:53:53.620000000',
#   'year': 1946,
#   'imdb': {'rating': 8.1, 'votes': 60271, 'id': 38355},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 32927, 'meter': 91},
#    'dvd': datetime.datetime(2000, 2, 15, 0, 0),
#    'critic': {'rating': 8.8, 'numReviews': 52, 'meter': 96},
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 23, 2),
#    'rotten': 2,
#    'production': 'Warner Bros. Pictures',
#    'fresh': 50}},
#  {'_id': ObjectId('573a1393f29313caabcdd6e7'),
#   'plot': "Chuck Scott gets a job as chauffeur to tough guy Eddie Roman; but Chuck's involvement with Eddie's fearful wife becomes a nightmare.",
#   'genres': ['Film-Noir'],
#   'runtime': 86,
#   'rated': 'APPROVED',
#   'cast': ['Robert Cummings',
#    'Michèle Morgan',
#    'Steve Cochran',
#    'Lloyd Corrigan'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDI3OTM4NzMtNzQxMC00M2YxLWFmOTctNmUyNDBmMzIwZGI0XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Chase',
#   'fullplot': "Returning a lost wallet gains unemployed veteran Chuck Scott a job as chauffeur to Eddie Roman, a seeming gangster whose enemies have a way of meeting violent ends. The job proves nerve-wracking, and soon Chuck finds himself pledged to help Eddie's lovely, fearful, prisoner-wife Lorna to escape. The result leaves Chuck caught like a rat in a trap, vainly seeking a way out through dark streets. But the real chase begins when the strange plot virtually starts all over again...",
#   'languages': ['English', 'Spanish'],
#   'released': datetime.datetime(1946, 11, 16, 0, 0),
#   'directors': ['Arthur Ripley'],
#   'writers': ['Philip Yordan (written for the screen by)',
#    'Cornell Woolrich (book)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-01 00:47:13.267000000',
#   'year': 1946,
#   'imdb': {'rating': 6.7, 'votes': 766, 'id': 38409},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 92, 'meter': 40},
#    'dvd': datetime.datetime(2003, 8, 5, 0, 0),
#    'production': 'VCI',
#    'lastUpdated': datetime.datetime(2015, 8, 20, 18, 14, 48)}},
#  {'_id': ObjectId('573a1393f29313caabcdd86b'),
#   'plot': 'A woman is asked to spy on a group of Nazi friends in South America. How far will she have to go to ingratiate herself with them?',
#   'genres': ['Drama', 'Film-Noir', 'Romance'],
#   'runtime': 101,
#   'rated': 'APPROVED',
#   'cast': ['Cary Grant', 'Ingrid Bergman', 'Claude Rains', 'Louis Calhern'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTc1NGViOTMtNjZhNS00OGY2LWI4MmItOWQwNTY4MDMzNWI3L2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Notorious',
#   'fullplot': "Following the conviction of her German father for treason against the U.S., Alicia Huberman takes to drink and men. She is approached by a government agent (T.R. Devlin) who asks her to spy on a group of her father's Nazi friends operating out of Rio de Janeiro. A romance develops between Alicia and Devlin, but she starts to get too involved in her work.",
#   'languages': ['English', 'French', 'Portuguese'],
#   'released': datetime.datetime(1946, 9, 6, 0, 0),
#   'directors': ['Alfred Hitchcock'],
#   'writers': ['Ben Hecht'],
#   'awards': {'wins': 5,
#    'nominations': 1,
#    'text': 'Nominated for 2 Oscars. Another 3 wins & 1 nomination.'},
#   'lastupdated': '2015-09-12 00:23:08.903000000',
#   'year': 1946,
#   'imdb': {'rating': 8.1, 'votes': 67596, 'id': 38787},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.1, 'numReviews': 35168, 'meter': 92},
#    'dvd': datetime.datetime(2001, 3, 13, 0, 0),
#    'critic': {'rating': 8.9, 'numReviews': 37, 'meter': 97},
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 3, 34),
#    'consensus': 'Sublime direction from Hitchcock, and terrific central performances from Ingrid Bergman and Cary Grant make this a bona-fide classic worthy of a re-visit.',
#    'rotten': 1,
#    'production': 'RKO Radio Pictures',
#    'fresh': 36}},
#  {'_id': ObjectId('573a1393f29313caabcdd8b6'),
#   'plot': 'An adventuresome young man goes off to find himself and loses his socialite fiancèe in the process. But when he returns 10 years later, she will stop at nothing to get him back, even though she is already married.',
#   'genres': ['Drama', 'Film-Noir'],
#   'runtime': 145,
#   'rated': 'APPROVED',
#   'cast': ['Tyrone Power', 'Gene Tierney', 'John Payne', 'Anne Baxter'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNmIwMDA3MzMtODY4OC00NjkxLWIyNGQtMTVhOGY4Nzc5ZDI0XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': "The Razor's Edge",
# ...
#   'writers': ['Jay Richard Kennedy (original story)',
#    'Jay Richard Kennedy (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-02-15 00:46:33.567000000',
#   'year': 1948,
#   'imdb': {'rating': 7.3, 'votes': 284, 'id': 40887},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 112, 'meter': 57},
#    'dvd': datetime.datetime(2007, 6, 5, 0, 0),
#    'production': 'Columbia Pictures',
#    'lastUpdated': datetime.datetime(2015, 8, 18, 18, 49)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcde169'),
#   'plot': "An embittered, vengeful POW stalks his former commanding officer who betrayed his men's planned escape attempt from a Nazi prison camp..",
#   'genres': ['Thriller', 'Film-Noir', 'Drama'],
#   'runtime': 82,
#   'rated': 'PASSED',
#   'cast': ['Van Heflin', 'Robert Ryan', 'Janet Leigh', 'Mary Astor'],
#   'title': 'Act of Violence',
#   'fullplot': 'War veteran Frank Enley seems to be a happily married small-town citizen until he realises Joe Parkson is in town. It seems Parkson is out for revenge because of something that happened in a German POW camp, and when a frightened Enley suddenly leaves for a convention in L.A., Parkson is close behind.',
#   'languages': ['English', 'German'],
#   'released': datetime.datetime(1948, 12, 21, 0, 0),
#   'directors': ['Fred Zinnemann'],
#   'writers': ['Robert L. Richards (screenplay)', 'Collier Young (story)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-09-15 04:38:16.153000000',
#   'year': 1948,
#   'imdb': {'rating': 7.5, 'votes': 2840, 'id': 41088},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 499, 'meter': 77},
#    'dvd': datetime.datetime(2007, 7, 31, 0, 0),
#    'critic': {'rating': 6.8, 'numReviews': 10, 'meter': 90},
#    'lastUpdated': datetime.datetime(2015, 7, 27, 18, 37, 1),
#    'rotten': 1,
#    'fresh': 9},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcde1f8'),
#   'plot': "On Chicago's South Side reporter Ed Ames finds the body of a dead girl. Her address book leads to a host of names of men frightened by her death but claiming never to have known her. Ames comes to know quite a lot, dangerously so.",
#   'genres': ['Drama', 'Film-Noir'],
#   'runtime': 86,
#   'rated': 'APPROVED',
#   'cast': ['Alan Ladd', 'Donna Reed', 'June Havoc', 'Irene Hervey'],
#   'num_mflix_comments': 1,
#   'title': 'Chicago Deadline',
#   'fullplot': "On Chicago's South Side reporter Ed Ames finds the body of a dead girl. Her address book leads to a host of names of men frightened by her death but claiming never to have known her. Ames comes to know quite a lot, dangerously so.",
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 10, 17, 0, 0),
#   'directors': ['Lewis Allen'],
#   'writers': ['Warren Duff (screenplay)', 'Tiffany Thayer (novel)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-25 00:56:38.993000000',
#   'year': 1949,
#   'imdb': {'rating': 6.5, 'votes': 154, 'id': 41243},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.4, 'numReviews': 44, 'meter': 100},
#    'production': 'Paramount Pictures',
#    'lastUpdated': datetime.datetime(2015, 8, 20, 19, 21, 2)}},
#  {'_id': ObjectId('573a1393f29313caabcde1fe'),
#   'plot': 'Boxer Midge Kelly rises to fame...mainly by stepping on other people.',
#   'genres': ['Drama', 'Film-Noir', 'Romance'],
#   'runtime': 99,
#   'rated': 'APPROVED',
#   'cast': ['Kirk Douglas',
#    'Marilyn Maxwell',
#    'Arthur Kennedy',
#    'Paul Stewart'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMzk0OGNhM2YtYWUxZS00YmFhLTk5ODMtMDdlNTQ4ZWY2OTYzL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Champion',
#   'fullplot': "Midge Kelly, hitchhiking west with lame brother Connie, is hustled unprepared into a pro boxing match. Though he's severely beaten, manager Tommy Haley finds him promising. Arrived in California, Midge and Connie find nothing but a menial job from which Midge gets relief by seducing Emma, a lovely young waitress. One shotgun marriage later, ambitious Midge falls back on the only option he knows: boxing. Seduced by cheering crowds, money, and a succession of blondes, Midge becomes more and more of a hero in public...and a heel in private.",
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 4, 9, 0, 0),
#   'directors': ['Mark Robson'],
#   'writers': ['Carl Foreman (screenplay)', 'Ring Lardner (story)'],
#   'awards': {'wins': 2,
#    'nominations': 9,
#    'text': 'Won 1 Oscar. Another 1 win & 9 nominations.'},
#   'lastupdated': '2015-08-23 00:18:57.173000000',
#   'year': 1949,
#   'imdb': {'rating': 7.5, 'votes': 2198, 'id': 41239},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.7, 'numReviews': 695, 'meter': 73},
#    'dvd': datetime.datetime(2013, 4, 22, 0, 0),
#    'critic': {'rating': 8.0, 'numReviews': 12, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 19, 8, 24),
#    'rotten': 1,
#    'production': 'United Artists',
#    'fresh': 11},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcde2db'),
#   'plot': "Clive Riordan plans a devilish revenge against his wife's lover.",
#   'genres': ['Crime', 'Film-Noir', 'Mystery'],
#   'runtime': 96,
#   'rated': 'Approved',
#   'cast': ['Robert Newton', 'Phil Brown', 'Sally Gray', 'Naunton Wayne'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZWNhZGIyZmQtM2UzYy00MzVkLWEzN2YtNmFhNGU2MGE2YmQwXkEyXkFqcGdeQXVyMTk2MzI2Ng@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Hidden Room',
#   'fullplot': "London psychiatrist Clive Riordan, royally fed up with the repeated affairs of his wife Storm, plots a seemingly 'perfect' revenge against her latest lover, American Bill Kronin. Catching them in the act, he marches Bill off at gunpoint; and from the viewpoint of Storm and the rest of the world, Bill simply vanishes. But there's far more to the meticulously worked out plot than Clive's victims suspect, with the end slowly preparing in his private laboratory. Enter a mild-mannered Scotland Yard man, who seemingly has no clue beyond a missing dog...",
#   'languages': ['English'],
#   'released': datetime.datetime(1950, 1, 8, 0, 0),
#   'directors': ['Edward Dmytryk'],
#   'writers': ['Alec Coppel (book)', 'Alec Coppel (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-02-19 00:58:02.427000000',
#   'year': 1949,
#   'imdb': {'rating': 7.5, 'votes': 839, 'id': 41460},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 258, 'meter': 87},
#    'production': 'Criterion Collection',
#    'lastUpdated': datetime.datetime(2015, 7, 13, 19, 5, 5)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcde2f7'),
#   'plot': 'In New York, after seven years in prison, the lawyer Max Monetti goes to the bank of his brothers Joe, Tony and Pietro Monetti and promises revenge to them. Then he visits his lover Irene ...',
#   'genres': ['Crime', 'Drama', 'Film-Noir'],
#   'runtime': 101,
#   'rated': 'APPROVED',
#   'cast': ['Edward G. Robinson',
#    'Susan Hayward',
#    'Richard Conte',
#    'Luther Adler'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZDJlYmUyNGEtMDNiMi00OTczLTg3NzQtZDQ5NjgzZmFlZmY4XkEyXkFqcGdeQXVyMjUxODE0MDY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'House of Strangers',
#   'fullplot': 'In New York, after seven years in prison, the lawyer Max Monetti goes to the bank of his brothers Joe, Tony and Pietro Monetti and promises revenge to them. Then he visits his lover Irene Bennett that asks him to forget the past and start a new life. Max recalls the early 30s, when he is the favorite son of his father Gino Monetti, who has a bank in the East Side. Gino is a tyrannical and egocentric self-made man that raises his family in an environment of hatred and Max is a competent lawyer engaged with Maria Domenico. When Max meets the confident Irene, he has a troubled love affair with her. In 1933, with the new Banking Act reaches Gino for misapplication of funds. Max plots a plan to help his father but is betrayed by his brothers. Now Max will see his brothers that have also being raised under the motto "Never Forgive, Never Forget".',
#   'languages': ['English', 'Italian'],
#   'released': datetime.datetime(1949, 7, 1, 0, 0),
#   'directors': ['Joseph L. Mankiewicz'],
#   'writers': ['Philip Yordan (screenplay)', 'Jerome Weidman (novel)'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-08-10 00:14:36.910000000',
#   'year': 1949,
#   'imdb': {'rating': 7.5, 'votes': 1686, 'id': 41487},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 354, 'meter': 75},
#    'dvd': datetime.datetime(2006, 6, 6, 0, 0),
#    'critic': {'rating': 6.2, 'numReviews': 5, 'meter': 80},
#    'lastUpdated': datetime.datetime(2015, 8, 31, 20, 21, 33),
#    'rotten': 1,
#    'fresh': 4},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcde417'),
#   'plot': 'An elderly countess strikes a bargain with the devil and exchanges her soul for the ability to always win at cards. An army officer, who is also a fanatic about cards, murders her for the ...',
#   'genres': ['Drama', 'Horror'],
#   'runtime': 95,
#   'cast': ['Anton Walbrook',
#    'Edith Evans',
#    'Yvonne Mitchell',
#    'Ronald Howard'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYTgzMGUzMmMtOWY1ZC00MzJjLWJmZjQtNDA1OWYxNTRjYWY1XkEyXkFqcGdeQXVyMTYzNTE3NDA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Queen of Spades',
#   'fullplot': "An elderly countess strikes a bargain with the devil and exchanges her soul for the ability to always win at cards. An army officer, who is also a fanatic about cards, murders her for the secret, then finds himself haunted by the woman's spirit.",
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 6, 30, 0, 0),
#   'directors': ['Thorold Dickinson'],
#   'writers': ['Rodney Ackland',
#    'Arthur Boys',
#    'Alexander Pushkin (short story "The Queen of Spades")'],
#   'awards': {'wins': 2,
#    'nominations': 1,
#    'text': 'Nominated for 1 BAFTA Film Award. Another 1 win & 1 nomination.'},
#   'lastupdated': '2015-08-12 00:51:11.610000000',
#   'year': 1949,
#   'imdb': {'rating': 7.4, 'votes': 820, 'id': 41776},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 377, 'meter': 68},
#    'dvd': datetime.datetime(2003, 5, 20, 0, 0),
#    'critic': {'rating': 8.2, 'numReviews': 5, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 22, 18, 5, 44),
#    'rotten': 0,
#    'production': 'HBO Video',
#    'fresh': 5}},
#  {'_id': ObjectId('573a1393f29313caabcde453'),
#   'plot': 'Homicide detective Mike Conovan investigates the shooting of fellow detective Monigan...who apparrently was moonlighting as guard for a bookie. He finds that all the bookies in town are ...',
#   'genres': ['Crime', 'Film-Noir', 'Drama'],
#   'runtime': 94,
#   'rated': 'PASSED',
#   'cast': ['Van Johnson', 'Arlene Dahl', 'Gloria DeHaven', 'Tom Drake'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMzUwNzE2NzQ4Nl5BMl5BanBnXkFtZTgwNDI1MjM2MzE@._V1._CR35,52,275,437_SX178_AL_.jpg',
#   'title': 'Scene of the Crime',
#   'fullplot': "Homicide detective Mike Conovan investigates the shooting of fellow detective Monigan...who apparrently was moonlighting as guard for a bookie. He finds that all the bookies in town are being robbed, most upsetting to the racket bosses who can't get normal police protection. Mike encounters blind alleys and double crosses, and is distracted by his wife's growing disenchantment. Lots of police slang.",
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 7, 28, 0, 0),
#   'directors': ['Roy Rowland'],
#   'writers': ['John Bartlow Martin (story)', 'Charles Schnee (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-09-17 04:41:18.333000000',
#   'year': 1949,
#   'imdb': {'rating': 6.6, 'votes': 573, 'id': 41847},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 40, 'meter': 25},
#    'dvd': datetime.datetime(2013, 1, 8, 0, 0),
#    'production': 'Warner Home Video',
#    'lastUpdated': datetime.datetime(2015, 7, 20, 19, 8, 14)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1393f29313caabcde460'),
#   'plot': "Over-the-hill boxer Bill 'Stoker' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money ...",
#   'genres': ['Film-Noir', 'Sport'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Robert Ryan', 'Audrey Totter', 'George Tobias', 'Alan Baxter'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjEwNjU3NzE1Nl5BMl5BanBnXkFtZTgwMjQ0MDgyMTE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Set-Up',
#   'fullplot': 'Over-the-hill boxer Bill \'Stoker\' Thompson insists he can still win, though his sexy wife Julie pleads with him to quit. But his manager Tiny is so confident he will lose, he takes money for a "dive" from tough gambler Little Boy...without bothering to tell Stoker. Tension builds as Stoker hopes to "take" Tiger Nelson, unaware of what will happen to him if he does.',
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 4, 2, 0, 0),
#   'directors': ['Robert Wise'],
#   'writers': ['Art Cohn (screenplay)',
#    'Joseph Moncure March (from the poem by)'],
#   'awards': {'wins': 3,
#    'nominations': 1,
#    'text': 'Nominated for 1 BAFTA Film Award. Another 2 wins & 1 nomination.'},
#   'lastupdated': '2015-08-26 00:13:18.837000000',
#   'year': 1949,
#   'imdb': {'rating': 7.8, 'votes': 5309, 'id': 41859},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 1692, 'meter': 88},
#    'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#    'critic': {'rating': 5.9, 'numReviews': 7, 'meter': 86},
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 33, 52),
#    'rotten': 1,
#    'fresh': 6}},
#  {'_id': ObjectId('573a1393f29313caabcde52f'),
#   'plot': 'To avoid the heat of a sweltering summer night a 9 year old Manhattan boy decides to sleep on the fire escape and witnesses a murder, no one will believe him.',
#   'genres': ['Drama', 'Film-Noir', 'Thriller'],
#   'runtime': 73,
#   'rated': 'APPROVED',
#   'cast': ['Barbara Hale', 'Arthur Kennedy', 'Paul Stewart', 'Ruth Roman'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZDUxOTIyZWMtMDM1MS00ZWE2LTg0MDktZjFmYmNlM2I4MmRiXkEyXkFqcGdeQXVyMTYzMTY1MjQ@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Window',
#   'fullplot': "At the age of 9, Tommy Woodry has a reputation for telling tall tales -- the latest one being that his family is moving from Manhattan to a ranch out west. When the landlord interrupts the Woodrys at dinner to show their about to be vacated apartment, the Woodrys tell Tommy enough is enough. Then that hot summer night Tommy decides to sleep on the fire escape -- outside the Kellerson's apartment, since it is a story higher and gets more breeze. Tommy sees the Kellersons kill a man. Tommy's parents and the police won't believe his story. But the Kellersons want to silence him.",
#   'languages': ['English'],
#   'released': datetime.datetime(1949, 7, 21, 0, 0),
#   'directors': ['Ted Tetzlaff'],
#   'writers': ['Mel Dinelli (screenplay)',
#    'Cornell Woolrich (based on a story by)'],
#   'awards': {'wins': 2,
#    'nominations': 2,
#    'text': 'Nominated for 1 Oscar. Another 1 win & 2 nominations.'},
#   'lastupdated': '2015-06-15 02:28:50.687000000',
#   'year': 1949,
#   'imdb': {'rating': 7.5, 'votes': 2005, 'id': 42046},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 600},
#    'production': 'RKO Radio Pictures',
#    'lastUpdated': datetime.datetime(2015, 8, 21, 18, 49, 8)}}]

# %% [markdown]
# #### Задача 1.5 — **1 балл**

# %% [markdown]
# Модифицируйте запрос из задачи 1.4 таким образом, чтобы осуществить _проекцию_: результатом выборки должен стать список словарей, каждый из которых содержит только два поля: `title` и `year`.
#
# Для справки о проекции см. документацию по методу `find()` в pymongo:
# https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html#pymongo.collection.Collection.find

# %%
# Запрашиваем документы из коллекции 'movies'
query = {"genres": {"$in": ["Film-Noir", "Horror"]},
         "year": {"$gte": 1940, "$lte": 1949}}

# Проекция
projection = {"title": 1, "year": 1, "_id": 0}

# Находим документы с применением проекции
movies = db.movies.find(query, projection)

# Преобразуем результат запроса в список и выводим его
list(movies)
# Out:
# [{'title': 'Black Friday', 'year': 1940},
#  {'title': 'The Letter', 'year': 1940},
#  {'title': 'The Wolf Man', 'year': 1941},
#  {'title': 'Cat People', 'year': 1942},
#  {'title': 'Hangmen Also Die!', 'year': 1943},
#  {'title': 'I Walked with a Zombie', 'year': 1943},
#  {'title': 'The Leopard Man', 'year': 1943},
#  {'title': 'Phantom of the Opera', 'year': 1943},
#  {'title': 'The Seventh Victim', 'year': 1943},
#  {'title': 'The Curse of the Cat People', 'year': 1944},
#  {'title': 'Double Indemnity', 'year': 1944},
#  {'title': 'Laura', 'year': 1944},
#  {'title': 'Murder, My Sweet', 'year': 1944},
#  {'title': 'The Body Snatcher', 'year': 1945},
#  {'title': 'Detour', 'year': 1945},
#  {'title': 'Dead of Night', 'year': 1945},
#  {'title': 'House of Dracula', 'year': 1945},
#  {'title': 'The House on 92nd Street', 'year': 1945},
#  {'title': 'Isle of the Dead', 'year': 1945},
#  {'title': 'Leave Her to Heaven', 'year': 1945},
#  {'title': 'Bedlam', 'year': 1946},
#  {'title': 'The Big Sleep', 'year': 1946},
#  {'title': 'The Chase', 'year': 1946},
#  {'title': 'Notorious', 'year': 1946},
#  {'title': "The Razor's Edge", 'year': 1946},
#  {'title': 'The Stranger', 'year': 1946},
#  {'title': 'Body and Soul', 'year': 1947},
#  {'title': 'Boomerang!', 'year': 1947},
#  {'title': 'A Double Life', 'year': 1947},
#  {'title': 'Kiss of Death', 'year': 1947},
#  {'title': 'Possessed', 'year': 1947},
#  {'title': 'An Act of Murder', 'year': 1948},
#  {'title': 'Bud Abbott Lou Costello Meet Frankenstein', 'year': 1948},
#  {'title': 'Berlin Express', 'year': 1948},
#  {'title': 'The Big Clock', 'year': 1948},
#  {'title': 'Call Northside 777', 'year': 1948},
#  {'title': 'Cry of the City', 'year': 1948},
#  {'title': 'Force of Evil', 'year': 1948},
#  {'title': 'He Walked by Night', 'year': 1948},
#  {'title': 'The Naked City', 'year': 1948},
#  {'title': 'Road House', 'year': 1948},
#  {'title': 'Sorry, Wrong Number', 'year': 1948},
#  {'title': 'The Street with No Name', 'year': 1948},
#  {'title': 'To the Ends of the Earth', 'year': 1948},
#  {'title': 'Act of Violence', 'year': 1948},
#  {'title': 'Chicago Deadline', 'year': 1949},
#  {'title': 'Champion', 'year': 1949},
#  {'title': 'The Hidden Room', 'year': 1949},
#  {'title': 'House of Strangers', 'year': 1949},
#  {'title': 'The Queen of Spades', 'year': 1949},
#  {'title': 'Scene of the Crime', 'year': 1949},
#  {'title': 'The Set-Up', 'year': 1949},
#  {'title': 'The Window', 'year': 1949}]

# %% [markdown]
# ### Упражнение 2. Конвейер агрегации

# %% [markdown]
# #### Задача 2.1 — **3 балла**

# %% [markdown]
# В рамках этой задачи требуется узнать, какие фильмы получили наибольшее число комментариев. Составьте для этого конвейер агрегации с перечисленными ниже этапами. Для удобства рекомендуется воспользоваться приложением Compass.
#
# 1. Сгруппировать документы коллекции `comments` по полю `movie_id` и подсчитать количество комментариев для каждого фильма, записав его в поле `count`.
# 1. Отсортировать получившийся набор данных по убыванию количества комментариев (так чтобы первый документ в этом наборе указывал на фильм с наибольшим количеством комментариев).
# 1. Используя оператор `$lookup`, присоединить коллекцию `movies` (по полю `movie_id`).
# 1. Выполнить проекцию, оставив в наборе данных только три поля: название фильма (`title`), год выпуска (`year`) и количество комментариев (поле `count`, добавленное на первом этапе). Для этого воспользуйтесь оператором `$project`: https://www.mongodb.com/docs/manual/reference/operator/aggregation/project/. Обратите внимание, что данные из коллекции `movies` (`title` и `year`) на этом этапе окажутся внутри массива.
# 1. Применить оператор `$unwind`, чтобы деконструировать этот массив. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/unwind/. В результате массив должен превратиться в одиночный объект.
# 1. Применить оператор `$addFields`, чтобы добавить поля `title` и `year` на вернхий уровень структуры документа. См. https://www.mongodb.com/docs/manual/reference/operator/aggregation/addFields/.
# 1. Еще раз выполнить проекцию, чтобы удалить поле с массивом.
#
# Ваш алгоритм решения может отличаться от приведенного здесь. Главное — достичь цели: получить плоский набор данных с тремя полями (`count` — количество комментариев, `year` — год выпуска, `title` — название фильма).
#
# Скопируйте полученный конвейер в этот документ в виде кода на Python и выведите его на экран в виде списка словарей.

# %%
# Создаем pipline
pipeline = [

    # Stage 1: Группировка и подсчет комментариев для каждого фильма
    {"$group": {
        "_id": "$movie_id",
        "count": {"$sum": 1}
    }},

    # Stage 2: Сортировка по убыванию количества комментариев
    {"$sort": {"count": -1}},

    # Stage 3: Присоединение информации о фильме из коллекции movies
    {"$lookup": {
        "from": "movies",
        "localField": "_id",
        "foreignField": "_id",
        "as": "movie_info"
    }},

    # Stage 4: Проекция, оставляющая только нужные поля
    {"$project": {
        "_id": 0,
        "count": 1,
        "movie_info.title": 1,
        "movie_info.year": 1
    }},

    # Stage 5: Развертывание массива с информацией о фильме
    {"$unwind": "$movie_info"},

    # Stage 6: Добавление полей title и year на верхний уровень структуры
    {"$addFields": {
        "title": "$movie_info.title",
        "year": "$movie_info.year"
    }},

    # Stage 7: Повторная проекция для удаления массива
    {"$project": {
        "title": 1,
        "year": 1,
        "count": 1
    }}
]

# Выполняем агрегационный запрос к коллекции 'comments' с использованием заданного 'pipeline'
result = db.comments.aggregate(pipeline)

# Преобразуем результат запроса в список
data = list(result)

# Выводим полученные данные
data
# Out:
# [{'count': 161, 'title': 'The Taking of Pelham 1 2 3', 'year': 2009},
#  {'count': 158, 'title': "Ocean's Eleven", 'year': 2001},
#  {'count': 158, 'title': 'About a Boy', 'year': 2002},
#  {'count': 158, 'title': '50 First Dates', 'year': 2004},
#  {'count': 158, 'title': 'Terminator Salvation', 'year': 2009},
#  {'count': 157, 'title': 'Sherlock Holmes', 'year': 2009},
#  {'count': 157, 'title': 'The Mummy', 'year': 1999},
#  {'count': 155, 'title': 'Hellboy II: The Golden Army', 'year': 2008},
#  {'count': 154,
#   'title': 'Anchorman: The Legend of Ron Burgundy',
#   'year': 2004},
#  {'count': 154, 'title': 'The Mummy Returns', 'year': 2001},
#  {'count': 153, 'title': 'American Pie', 'year': 1999},
#  {'count': 153, 'title': 'Bruce Almighty', 'year': 2003},
#  {'count': 153,
#   'title': "Pirates of the Caribbean: At World's End",
#   'year': 2007},
#  {'count': 153, 'title': 'Wanted', 'year': 2008},
#  {'count': 153, 'title': 'Cinderella', 'year': 1950},
#  {'count': 153, 'title': 'Mission: Impossible', 'year': 1996},
#  {'count': 153, 'title': 'X-Men', 'year': 2000},
#  {'count': 153, 'title': 'E.T. the Extra-Terrestrial', 'year': 1982},
#  {'count': 152, 'title': 'The Ring', 'year': 2002},
#  {'count': 152, 'title': 'Gladiator', 'year': 2000},
#  {'count': 151, 'title': 'Meet the Fockers', 'year': 2004},
#  {'count': 151, 'title': 'The Mask', 'year': 1994},
#  {'count': 151, 'title': 'The Matrix Reloaded', 'year': 2003},
#  {'count': 150, 'title': 'Big Daddy', 'year': 1999},
#  {'count': 150, 'title': 'Toy Story 2', 'year': 1999},
#  {'count': 148, 'title': 'I Am Legend', 'year': 2007},
#  {'count': 148, 'title': 'Braveheart', 'year': 1995},
#  {'count': 148, 'title': 'Jurassic Park', 'year': 1993},
#  {'count': 147, 'title': 'Jaws', 'year': 1975},
#  {'count': 147, 'title': 'The Express', 'year': 2008},
#  {'count': 147, 'title': 'Scary Movie', 'year': 2000},
#  {'count': 146, 'title': 'I Now Pronounce You Chuck & Larry', 'year': 2007},
#  {'count': 146, 'title': 'Twister', 'year': 1996},
#  {'count': 145, 'title': 'Cast Away', 'year': 2000},
#  {'count': 145, 'title': '300', 'year': 2006},
#  {'count': 145, 'title': 'Dumb & Dumber', 'year': 1994},
#  {'count': 144, 'title': 'King Kong', 'year': 2005},
#  {'count': 144, 'title': 'School of Rock', 'year': 2003},
#  {'count': 144, 'title': 'Spider-Man 3', 'year': 2007},
#  {'count': 144, 'title': 'Aladdin', 'year': 1992},
#  {'count': 144, 'title': 'The Last House on the Left', 'year': 2009},
#  {'count': 144, 'title': 'The Green Mile', 'year': 1999},
#  {'count': 144, 'title': 'Saving Private Ryan', 'year': 1998},
#  {'count': 144, 'title': 'The Hangover', 'year': 2009},
#  {'count': 144, 'title': 'Zoolander', 'year': 2001},
#  {'count': 144, 'title': 'Hostel: Part II', 'year': 2007},
#  {'count': 144, 'title': 'Dègkeselyè', 'year': 1982},
#  {'count': 144, 'title': 'The Simpsons Movie', 'year': 2007},
#  {'count': 144, 'title': 'I Love You, Man', 'year': 2009},
#  {'count': 143,
#   'title': 'Harry Potter and the Chamber of Secrets',
#   'year': 2002},
#  {'count': 143, 'title': 'The Jungle Creature: Hugo', 'year': 1993},
#  {'count': 143, 'title': 'Up', 'year': 2009},
#  {'count': 143, 'title': '8 Mile', 'year': 2002},
#  {'count': 143, 'title': 'Ice Age', 'year': 2002},
#  {'count': 143, 'title': 'Kill Bill: Vol. 1', 'year': 2003},
#  {'count': 143, 'title': 'Rush Hour 2', 'year': 2001},
#  {'count': 142, 'title': "Ocean's Twelve", 'year': 2004},
#  {'count': 142, 'title': 'Speed', 'year': 1994},
#  {'count': 142, 'title': 'Back to the Future Part II', 'year': 1989},
#  {'count': 142, 'title': 'Shutter Island', 'year': 2010},
#  {'count': 142, 'title': 'Star Trek', 'year': 2009},
#  {'count': 141, 'title': 'The Princess Diaries', 'year': 2001},
#  {'count': 141, 'title': '1408', 'year': 2007},
#  {'count': 141, 'title': 'Live Free or Die Hard', 'year': 2007},
#  {'count': 141, 'title': 'Freaky Friday', 'year': 2003},
#  {'count': 141, 'title': 'Rush Hour', 'year': 1998},
#  {'count': 141, 'title': 'Evan Almighty', 'year': 2007},
#  {'count': 141, 'title': 'Billy Madison', 'year': 1995},
#  {'count': 140, 'title': 'Cheaper by the Dozen', 'year': 2003},
#  {'count': 140, 'title': 'X-Men 2', 'year': 2003},
#  {'count': 140, 'title': 'War of the Worlds', 'year': 2005},
#  {'count': 140, 'title': 'Mr. & Mrs. Smith', 'year': 2005},
#  {'count': 140, 'title': 'The Bourne Ultimatum', 'year': 2007},
#  {'count': 140, 'title': 'Back to the Future Part III', 'year': 1990},
#  {'count': 140, 'title': 'Ghost Rider', 'year': 2007},
#  {'count': 140, 'title': 'Men in Black II', 'year': 2002},
#  {'count': 139, 'title': 'Saw VI', 'year': 2009},
#  {'count': 139, 'title': 'Ace Ventura: When Nature Calls', 'year': 1995},
#  {'count': 139, 'title': 'The Matrix Revolutions', 'year': 2003},
#  {'count': 139, 'title': 'Happy Gilmore', 'year': 1996},
#  {'count': 139, 'title': 'Liar Liar', 'year': 1997},
#  {'count': 139, 'title': 'V for Vendetta', 'year': 2005},
#  {'count': 139, 'title': 'The Wizard of Oz', 'year': 1939},
#  {'count': 138,
#   'title': 'Sweeney Todd: The Demon Barber of Fleet Street',
#   'year': 2007},
#  {'count': 138, 'title': 'Gone in Sixty Seconds', 'year': 2000},
#  {'count': 138, 'title': 'The Matrix', 'year': 1999},
#  {'count': 138, 'title': 'Donnie Darko', 'year': 2001},
#  {'count': 138, 'title': 'Shark Tale', 'year': 2004},
#  {'count': 138, 'title': 'Men in Black 3', 'year': 2012},
#  {'count': 138,
#   'title': "Harry Potter and the Sorcerer's Stone",
#   'year': 2001},
#  {'count': 138, 'title': 'How to Lose a Guy in 10 Days', 'year': 2003},
#  {'count': 138, 'title': 'How the Grinch Stole Christmas', 'year': 2000},
#  {'count': 138, 'title': 'A Christmas Carol', 'year': 2009},
#  {'count': 137, 'title': 'Elf', 'year': 2003},
#  {'count': 137, 'title': 'Fight Club', 'year': 1999},
#  {'count': 137, 'title': 'Independence Day', 'year': 1996},
#  {'count': 137, 'title': 'The 40-Year-Old Virgin', 'year': 2005},
#  {'count': 137, 'title': 'My Big Fat Greek Wedding', 'year': 2002},
#  {'count': 137,
#   'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'year': 2005},
#  {'count': 136, 'title': 'Beetlejuice', 'year': 1988},
#  {'count': 136, 'title': 'The Waterboy', 'year': 1998},
#  {'count': 136, 'title': 'Rocky', 'year': 1976},
#  {'count': 136, 'title': 'The Nightmare Before Christmas', 'year': 1993},
#  {'count': 136, 'title': 'Cast Away', 'year': 2000},
#  {'count': 136, 'title': 'The Bourne Identity', 'year': 2002},
#  {'count': 136, 'title': 'The Dark Knight', 'year': 2008},
#  {'count': 136, 'title': 'Forrest Gump', 'year': 1994},
#  {'count': 136,
#   'title': 'Harry Potter and the Prisoner of Azkaban',
#   'year': 2004},
#  {'count': 135, 'title': 'Push', 'year': 2009},
#  {'count': 135, 'title': 'Signs', 'year': 2002},
#  {'count': 135,
#   'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'year': 2005},
#  {'count': 135, 'title': 'Honey, I Shrunk the Kids', 'year': 1989},
#  {'count': 135, 'title': 'Indiana Jones and the Last Crusade', 'year': 1989},
#  {'count': 135, 'title': 'Bring It On', 'year': 2000},
#  {'count': 134, 'title': 'Transformers: Revenge of the Fallen', 'year': 2009},
#  {'count': 134, 'title': 'American Pie 2', 'year': 2001},
#  {'count': 134, 'title': 'Spider-Man 2', 'year': 2004},
#  {'count': 134, 'title': 'The Jungle Book', 'year': 1967},
#  {'count': 134,
#   'title': 'Fantastic 4: Rise of the Silver Surfer',
#   'year': 2007},
#  {'count': 134, 'title': 'Monsters, Inc.', 'year': 2001},
#  {'count': 134, 'title': 'Sin City', 'year': 2005},
#  {'count': 134, 'title': 'The Mummy', 'year': 1999},
#  {'count': 134, 'title': 'Miss Congeniality', 'year': 2000},
#  {'count': 134, 'title': 'Fantastic Four', 'year': 2005},
#  {'count': 134, 'title': 'Beauty and the Beast', 'year': 1991},
#  {'count': 134, 'title': 'The Uninvited', 'year': 2009},
#  {'count': 133, 'title': 'The Ugly Truth', 'year': 2009},
#  {'count': 133,
#   'title': 'The Lord of the Rings: The Return of the King',
#   'year': 2003},
#  {'count': 133, 'title': 'The Fast and the Furious', 'year': 2001},
#  {'count': 133, 'title': 'Shrek 2', 'year': 2004},
#  {'count': 133, 'title': 'Blades of Glory', 'year': 2007},
#  {'count': 132, 'title': 'Catch Me If You Can', 'year': 2002},
#  {'count': 132, 'title': 'Men in Black', 'year': 1997},
#  {'count': 132, 'title': 'Shrek the Third', 'year': 2007},
#  {'count': 132, 'title': '2 Fast 2 Furious', 'year': 2003},
#  {'count': 132, 'title': 'Free Willy', 'year': 1993},
#  {'count': 132, 'title': 'Ace Ventura: Pet Detective', 'year': 1994},
#  {'count': 132, 'title': 'The Lion King', 'year': 1994},
#  {'count': 132, 'title': "The Time Traveler's Wife", 'year': 2009},
#  {'count': 131, 'title': 'Shark Tale', 'year': 2004},
#  {'count': 131, 'title': 'Drag Me to Hell', 'year': 2009},
#  {'count': 131, 'title': 'The Godfather', 'year': 1972},
#  {'count': 131, 'title': 'The Shawshank Redemption', 'year': 1994},
#  {'count': 131, 'title': 'American Beauty', 'year': 1999},
#  {'count': 131, 'title': 'Shrek', 'year': 2001},
#  {'count': 131, 'title': 'The Sixth Sense', 'year': 1999},
#  {'count': 131, 'title': 'Doctor Dolittle', 'year': 1998},
#  {'count': 131, 'title': 'Star Wars: Episode IV - A New Hope', 'year': 1977},
#  {'count': 131, 'title': 'Meet the Parents', 'year': 2000},
#  {'count': 131, 'title': 'Toy Story', 'year': 1995},
#  {'count': 131, 'title': 'The Unborn', 'year': 2009},
#  {'count': 130, 'title': 'G.I. Joe: The Rise of Cobra', 'year': 2009},
#  {'count': 130, 'title': 'The Day After Tomorrow', 'year': 2004},
#  {'count': 130, 'title': 'Pretty Woman', 'year': 1990},
#  {'count': 130, 'title': 'Hook', 'year': 1991},
#  {'count': 130, 'title': 'Home Alone', 'year': 1990},
#  {'count': 130, 'title': 'Ice Age: The Meltdown', 'year': 2006},
#  {'count': 129, 'title': 'The Dark Knight Rises', 'year': 2012},
#  {'count': 129, 'title': 'Bad Boys', 'year': 1995},
#  {'count': 129, 'title': 'Avatar', 'year': 2009},
#  {'count': 128, 'title': 'Sister Act', 'year': 1992},
#  {'count': 128, 'title': 'Night at the Museum', 'year': 2006},
#  {'count': 128, 'title': 'The Curious Case of Benjamin Button', 'year': 2008},
#  {'count': 128, 'title': 'Troy', 'year': 2004},
#  {'count': 128, 'title': 'X-Men', 'year': 2000},
#  {'count': 128, 'title': 'A Cinderella Story', 'year': 2004},
#  {'count': 128, 'title': 'Mary Poppins', 'year': 1964},
#  {'count': 128, 'title': 'The Little Mermaid', 'year': 1989},
#  {'count': 128, 'title': 'Stop-Loss', 'year': 2008},
#  {'count': 128, 'title': 'Mr. Deeds', 'year': 2002},
#  {'count': 128,
#   'title': 'Austin Powers: International Man of Mystery',
#   'year': 1997},
#  {'count': 128, 'title': 'Titanic', 'year': 1997},
#  {'count': 128, 'title': 'A Walk to Remember', 'year': 2002},
#  {'count': 128, 'title': 'Liar Liar', 'year': 1997},
#  {'count': 127,
#   'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'year': 2003},
#  {'count': 127, 'title': 'The Wedding Singer', 'year': 1998},
#  {'count': 127,
#   'title': 'The Lord of the Rings: The Two Towers',
#   'year': 2002},
#  {'count': 127, 'title': 'Slumdog Millionaire', 'year': 2008},
#  {'count': 127, 'title': 'Funny People', 'year': 2009},
#  {'count': 127, 'title': 'Inglourious Basterds', 'year': 2009},
#  {'count': 127, 'title': 'The Incredible Hulk', 'year': 2008},
#  {'count': 127, 'title': 'Taken', 'year': 2008},
#  {'count': 126, 'title': 'Raiders of the Lost Ark', 'year': 1981},
#  {'count': 126, 'title': 'Mrs. Doubtfire', 'year': 1993},
#  {'count': 126, 'title': 'Anger Management', 'year': 2003},
#  {'count': 126, 'title': 'Lady and the Tramp', 'year': 1955},
#  {'count': 126, 'title': 'Austin Powers in Goldmember', 'year': 2002},
#  {'count': 125, 'title': 'Batman', 'year': 1989},
#  {'count': 125, 'title': 'Terminator 2: Judgment Day', 'year': 1991},
#  {'count': 125, 'title': 'Pearl Harbor', 'year': 2001},
#  {'count': 124,
#   'title': 'Austin Powers: The Spy Who Shagged Me',
#   'year': 1999},
#  {'count': 124, 'title': 'Armageddon', 'year': 1998},
#  {'count': 123, 'title': 'National Treasure: Book of Secrets', 'year': 2007},
#  {'count': 123, 'title': 'Scary Movie', 'year': 2000},
#  {'count': 123, 'title': 'Cars', 'year': 2006},
#  {'count': 123,
#   'title': 'Harry Potter and the Half-Blood Prince',
#   'year': 2009},
#  {'count': 122, 'title': 'Fighting', 'year': 2009},
#  {'count': 122, 'title': "Ocean's Thirteen", 'year': 2007},
#  {'count': 122, 'title': 'The Proposal', 'year': 2009},
#  {'count': 122, 'title': 'The End of a Mystery', 'year': 2003},
#  {'count': 122, 'title': 'The Shawshank Redemption', 'year': 1994},
#  {'count': 122, 'title': 'The Stepfather', 'year': 2009},
#  {'count': 121, 'title': 'The Silence of the Lambs', 'year': 1991},
#  {'count': 121, 'title': 'Quarantine', 'year': 2008},
#  {'count': 121, 'title': "A Bug's Life", 'year': 1998},
#  {'count': 121, 'title': 'Pulp Fiction', 'year': 1994},
#  {'count': 121, 'title': 'Madagascar', 'year': 2005},
#  {'count': 121, 'title': 'The Invention of Lying', 'year': 2009},
#  {'count': 121, 'title': 'G-Force', 'year': 2009},
#  {'count': 120, 'title': 'Willy Wonka & the Chocolate Factory', 'year': 1971},
#  {'count': 120, 'title': 'Finding Nemo', 'year': 2003},
#  {'count': 119, 'title': 'Watchmen', 'year': 2009},
#  {'count': 119, 'title': 'The Hunger Games', 'year': 2012},
#  {'count': 119, 'title': '10 Things I Hate About You', 'year': 1999},
#  {'count': 119, 'title': 'Jumanji', 'year': 1995},
#  {'count': 119, 'title': 'Grease', 'year': 1978},
#  {'count': 119, 'title': 'Harry Potter and the Goblet of Fire', 'year': 2005},
#  {'count': 118, 'title': '101 Dalmatians', 'year': 1961},
#  {'count': 117, 'title': 'The Avengers', 'year': 2012},
#  {'count': 117,
#   'title': 'Star Wars: Episode II - Attack of the Clones',
#   'year': 2002},
#  {'count': 117, 'title': 'Orphan', 'year': 2009},
#  {'count': 117, 'title': 'Saw II', 'year': 2005},
#  {'count': 116, 'title': 'Love Actually', 'year': 2003},
#  {'count': 116, 'title': 'Scary Movie 3', 'year': 2003},
#  {'count': 115, 'title': 'Sweet Home Alabama', 'year': 2002},
#  {'count': 115,
#   'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': 1980},
#  {'count': 115,
#   'title': 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   'year': 2006},
#  {'count': 115, 'title': 'Scary Movie 2', 'year': 2001},
#  {'count': 115, 'title': 'Edward Scissorhands', 'year': 1990},
#  {'count': 115, 'title': 'How to Lose a Guy in 10 Days', 'year': 2003},
#  {'count': 115, 'title': 'The Departed', 'year': 2006},
#  {'count': 115, 'title': 'Dirty Dancing', 'year': 1987},
#  {'count': 114, 'title': 'Hairspray', 'year': 2007},
#  {'count': 114,
#   'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'year': 2001},
#  {'count': 113, 'title': 'Disturbia', 'year': 2007},
#  {'count': 111, 'title': 'American Gangster', 'year': 2007},
#  {'count': 111, 'title': 'District 9', 'year': 2009},
#  {'count': 111, 'title': 'Coyote Ugly', 'year': 2000},
#  {'count': 111, 'title': "Charlie's Angels", 'year': 2000},
#  {'count': 109, 'title': 'The Amazing Spider-Man', 'year': 2012},
#  {'count': 108, 'title': 'Home Alone 2: Lost in New York', 'year': 1992},
#  {'count': 107, 'title': 'Norbit', 'year': 2007},
#  {'count': 5, 'title': 'The Cure', 'year': 1995},
#  {'count': 4, 'title': 'Compliance', 'year': 2012},
#  {'count': 4, 'title': 'Play It Again, Sam', 'year': 1972},
#  {'count': 4,
#   'title': 'Cowards Bend the Knee or The Blue Hands',
#   'year': 2003},
#  {'count': 4, 'title': 'The Women', 'year': 2008},
#  {'count': 4, 'title': 'Night Catches Us', 'year': 2010},
#  {'count': 4, 'title': 'Splice', 'year': 2009},
#  {'count': 3, 'title': 'Bleak Night', 'year': 2010},
#  {'count': 3, 'title': 'From Beyond', 'year': 1986},
#  {'count': 3, 'title': "Dead Man's Walk", 'year': 1996},
#  {'count': 3, 'title': 'Rabbit è la Berlin', 'year': 2009},
#  {'count': 3, 'title': 'Tired Moonlight', 'year': 2015},
#  {'count': 3, 'title': "Everybody's Famous!", 'year': 2000},
#  {'count': 3, 'title': 'When Good Ghouls Go Bad', 'year': 2001},
#  {'count': 3, 'title': 'American Courtesans', 'year': 2013},
#  {'count': 3, 'title': 'Inherent Vice', 'year': 2014},
#  {'count': 3, 'title': 'The Valet', 'year': 2006},
#  {'count': 3, 'title': 'The Unknown Woman', 'year': 2011},
#  {'count': 3, 'title': 'Comeback Season', 'year': 2006},
#  {'count': 3, 'title': 'Scott Joplin', 'year': 1977},
#  {'count': 3, 'title': 'Cube Zero', 'year': 2004},
#  {'count': 3, 'title': 'Drifting Clouds', 'year': 1996},
#  {'count': 3, 'title': 'Green Dragon', 'year': 2001},
#  {'count': 3, 'title': 'Taira Clan Saga', 'year': 1955},
#  {'count': 3, 'title': 'Olympus Has Fallen', 'year': 2013},
#  {'count': 3, 'title': "Betsy's Wedding", 'year': 1990},
#  {'count': 3, 'title': 'The Dark House', 'year': 2009},
#  {'count': 3, 'title': 'Exists', 'year': 2014},
#  {'count': 3, 'title': 'Metrobranding', 'year': 2010},
#  {'count': 3, 'title': 'They Are All Dead', 'year': 2014},
#  {'count': 3, 'title': 'Slice', 'year': 2009},
#  {'count': 3, 'title': 'The Shaman', 'year': 2015},
#  {'count': 3, 'title': 'Epic Movie', 'year': 2007},
#  {'count': 3, 'title': '45 Years', 'year': 2015},
#  {'count': 3, 'title': 'The House by the Lake', 'year': 1976},
#  {'count': 3, 'title': 'Jesse Stone: Benefit of the Doubt', 'year': 2012},
#  {'count': 3, 'title': '3 1/2 Minutes, Ten Bullets', 'year': 2015},
#  {'count': 3, 'title': 'La buena nueva', 'year': 2008},
#  {'count': 3, 'title': 'Twice in a Lifetime', 'year': 1985},
#  {'count': 3, 'title': 'Deterrence', 'year': 1999},
#  {'count': 3, 'title': 'Cesar Chavez', 'year': 2014},
#  {'count': 3, 'title': 'The Cow', 'year': 1989},
#  {'count': 3, 'title': 'Midnight Lace', 'year': 1960},
#  {'count': 3, 'title': 'Mr. Average', 'year': 2006},
#  {'count': 3, 'title': '61*', 'year': 2001},
#  {'count': 3, 'title': 'Palimpsest', 'year': 2006},
#  {'count': 3, 'title': 'Silent Running', 'year': 1972},
#  {'count': 3, 'title': 'Obitaemyy ostrov. Skhvatka', 'year': 2009},
#  {'count': 3, 'title': 'Exte: Hair Extensions', 'year': 2007},
#  {'count': 3, 'title': 'A Wife Confesses', 'year': 1961},
#  {'count': 3, 'title': 'Jibeuro ganeun gil', 'year': 2013},
#  {'count': 3, 'title': 'Upstream', 'year': 1927},
#  {'count': 3, 'title': 'Plastic', 'year': 2014},
#  {'count': 3, 'title': 'Forgotten Silver', 'year': 1995},
#  {'count': 3, 'title': 'Footsteps in the Fog', 'year': 1955},
#  {'count': 3, 'title': 'Happenstance', 'year': 2000},
#  {'count': 3, 'title': 'The Dark Side of Chocolate', 'year': 2010},
#  {'count': 3, 'title': 'I Am So Proud of You', 'year': 2008},
#  {'count': 3, 'title': 'Bionicle 3: Web of Shadows', 'year': 2005},
#  {'count': 3, 'title': 'Pink Saris', 'year': 2010},
#  {'count': 3, 'title': '3rd World Hero', 'year': 2000},
#  {'count': 3, 'title': 'Wah-Wah', 'year': 2005},
#  {'count': 3, 'title': 'Return to Paradise', 'year': 1998},
#  {'count': 3, 'title': 'Bride Wars', 'year': 2009},
#  {'count': 3, 'title': 'Honey I Blew Up the Kid', 'year': 1992},
#  {'count': 3, 'title': 'Hitler: The Rise of Evil', 'year': 2003},
#  {'count': 3, 'title': 'Stand Clear of the Closing Doors', 'year': 2013},
#  {'count': 3, 'title': 'Christmas in Connecticut', 'year': 1992},
#  {'count': 3, 'title': 'Jurassic Park III', 'year': 2001},
#  {'count': 3, 'title': "Lilian's Story", 'year': 1996},
#  {'count': 3, 'title': 'Great Migrations', 'year': 2010},
#  {'count': 3, 'title': 'Gangster Squad', 'year': 2013},
#  {'count': 3, 'title': 'Beauty Day', 'year': 2011},
#  {'count': 3, 'title': 'Euridice BA 2O37', 'year': 1975},
#  {'count': 3, 'title': 'Nacho Libre', 'year': 2006},
#  {'count': 3, 'title': 'Cairo Time', 'year': 2009},
#  {'count': 3, 'title': 'Date Night', 'year': 2010},
#  {'count': 3, 'title': 'High Spirits', 'year': 1988},
#  {'count': 3, 'title': 'Mystery Men', 'year': 1999},
#  {'count': 3, 'title': 'Black Cloud', 'year': 2004},
#  {'count': 3, 'title': 'The Rising Place', 'year': 2001},
#  {'count': 3, 'title': 'Bonhoeffer: Agent of Grace', 'year': 2000},
#  {'count': 3, 'title': 'The Boys of St. Vincent', 'year': 1992},
#  {'count': 3, 'title': 'Batman: Gotham Knight', 'year': 2008},
#  {'count': 3, 'title': 'Chronicle of Poor Lovers', 'year': 1954},
#  {'count': 3, 'title': 'Naming Number Two', 'year': 2006},
#  {'count': 3, 'title': 'Someone Like You', 'year': 2009},
#  {'count': 3, 'title': 'The Terminal', 'year': 2004},
#  {'count': 3, 'title': 'Duelul', 'year': 1981},
#  {'count': 3, 'title': 'Black Robe', 'year': 1991},
#  {'count': 3, 'title': 'Roots', 'year': 1977},
#  {'count': 3, 'title': 'The House', 'year': 1997},
#  {'count': 3, 'title': 'The Apartment', 'year': 1960},
#  {'count': 3, 'title': 'Cold Feet', 'year': 1989},
#  {'count': 3, 'title': 'Pom Poko', 'year': 1994},
#  {'count': 3, 'title': 'Midnight FM', 'year': 2010},
#  {'count': 3, 'title': "Jackie Chan's First Strike", 'year': 1996},
#  {'count': 3, 'title': 'The Mighty Ducks', 'year': 1992},
#  {'count': 3, 'title': 'Yesterday, Today and Tomorrow', 'year': 1963},
#  {'count': 3, 'title': 'Without Men', 'year': 2011},
#  {'count': 3, 'title': 'Proteus', 'year': 2003},
#  {'count': 3, 'title': 'Federal Hill', 'year': 1994},
#  {'count': 3, 'title': 'Ten Skies', 'year': 2004},
#  {'count': 3, 'title': 'Monster High: Friday Night Frights', 'year': 2013},
#  {'count': 3, 'title': 'Bringing Ashley Home', 'year': 2011},
#  {'count': 3, 'title': 'The Cincinnati Kid', 'year': 1965},
#  {'count': 3, 'title': 'Moebius', 'year': 1996},
#  {'count': 3, 'title': 'Werner - Beinhart!', 'year': 1990},
#  {'count': 3, 'title': 'The Moth Diaries', 'year': 2011},
#  {'count': 3, 'title': 'The Promised Land', 'year': 1975},
#  {'count': 3, 'title': 'The Roman Spring of Mrs. Stone', 'year': 1961},
#  {'count': 3, 'title': 'La Cage aux Folles', 'year': 1978},
#  {'count': 3, 'title': 'Peter and Vandy', 'year': 2009},
#  {'count': 3, 'title': 'Amistad', 'year': 1997},
#  {'count': 3, 'title': "That's Entertainment, Part II", 'year': 1976},
#  {'count': 3, 'title': 'Duck, You Sucker', 'year': 1971},
#  {'count': 3, 'title': "Occupe-toi d'Amèlie..!", 'year': 1949},
#  {'count': 3, 'title': 'Metalhead', 'year': 2013},
#  {'count': 3, 'title': 'Lord of Darkness', 'year': 2012},
#  {'count': 3, 'title': 'The Saboteurs', 'year': 2015},
#  {'count': 3, 'title': 'Robin-B-Hood', 'year': 2006},
#  {'count': 3, 'title': 'Misconception', 'year': 2014},
#  {'count': 3, 'title': 'A True Mob Story', 'year': 1998},
#  {'count': 3, 'title': 'Syriana', 'year': 2005},
#  {'count': 3, 'title': 'Nas: Time Is Illmatic', 'year': 2014},
#  {'count': 3, 'title': 'Chile, the Obstinate Memory', 'year': 1997},
#  {'count': 3, 'title': 'Bartok the Magnificent', 'year': 1999},
#  {'count': 3,
#   'title': 'Never Tear Us Apart: The Untold Story of INXS',
#   'year': 2014},
#  {'count': 3, 'title': 'SAGA: Curse of the Shadow', 'year': 2013},
#  {'count': 3, 'title': 'King & Country', 'year': 1964},
#  {'count': 3, 'title': "The King's Speech", 'year': 2010},
#  {'count': 3, 'title': 'Return of the Living Dead III', 'year': 1993},
#  {'count': 3, 'title': 'Horror Express', 'year': 1972},
#  {'count': 3, 'title': 'The Motorcycle Diaries', 'year': 2004},
#  {'count': 3, 'title': 'Overheard 2', 'year': 2011},
#  {'count': 3, 'title': 'Kiss Kiss Bang Bang', 'year': 2005},
#  {'count': 3, 'title': 'Good Neighbors', 'year': 2010},
#  {'count': 3, 'title': "Je t'aime je t'aime", 'year': 1968},
#  {'count': 3, 'title': 'The Boxer', 'year': 1997},
#  {'count': 3, 'title': 'City of Men', 'year': 2007},
#  {'count': 3, 'title': 'Dig!', 'year': 2004},
#  {'count': 3, 'title': 'Macario', 'year': 1960},
#  {'count': 3, 'title': 'Max Dugan Returns', 'year': 1983},
#  {'count': 2, 'title': 'Larry Kramer in Love and Anger', 'year': 2015},
#  {'count': 2, 'title': 'Spun', 'year': 2002},
#  {'count': 2, 'title': 'Notting Hill', 'year': 1999},
#  {'count': 2, 'title': 'Iron Sky', 'year': 2012},
#  {'count': 2, 'title': 'Dog Day Afternoon', 'year': 1975},
#  {'count': 2, 'title': 'Anna M.', 'year': 2007},
#  {'count': 2, 'title': 'Trench Road', 'year': 2004},
#  {'count': 2, 'title': 'Tizoc', 'year': 1957},
#  {'count': 2, 'title': 'Hush!', 'year': 2001},
#  {'count': 2, 'title': 'The Book of Life', 'year': 2014},
#  {'count': 2, 'title': 'Bessie', 'year': 2015},
#  {'count': 2, 'title': 'Lèon: The Professional', 'year': 1994},
#  {'count': 2, 'title': 'An American Girl Adventure', 'year': 2005},
#  {'count': 2, 'title': 'The Kite Runner', 'year': 2007},
#  {'count': 2, 'title': 'John Adams', 'year': 2008},
#  {'count': 2, 'title': 'O Lucky Man!', 'year': 1973},
#  {'count': 2, 'title': 'Happiness', 'year': 1998},
#  {'count': 2, 'title': "Feudin' Fools", 'year': 1952},
#  {'count': 2, 'title': 'Gas, Inspector Palmu!', 'year': 1961},
#  {'count': 2, 'title': 'Continental, un film sans fusil', 'year': 2007},
#  {'count': 2, 'title': 'Utomlyonnye solntsem 2: Predstoyanie', 'year': 2010},
#  {'count': 2, 'title': 'Beautiful', 'year': 2009},
#  {'count': 2, 'title': 'Brother', 'year': 2000},
#  {'count': 2, 'title': 'The Theory of Everything', 'year': 2014},
#  {'count': 2, 'title': "I Don't Kiss", 'year': 1991},
#  {'count': 2, 'title': 'Swimming with Sharks', 'year': 1994},
#  {'count': 2, 'title': 'Commando', 'year': 2013},
#  {'count': 2, 'title': 'Waxwork', 'year': 1988},
#  {'count': 2, 'title': 'Imperial Dreams', 'year': 2014},
#  {'count': 2, 'title': 'Verlengd weekend', 'year': 2005},
#  {'count': 2,
#   'title': 'Anacondas: The Hunt for the Blood Orchid',
#   'year': 2004},
#  {'count': 2, 'title': 'The 6th Day', 'year': 2000},
#  {'count': 2, 'title': 'Goodnight, Mister Tom', 'year': 1998},
#  {'count': 2, 'title': 'Step Up', 'year': 2006},
#  {'count': 2, 'title': 'The Bridge of San Luis Rey', 'year': 2004},
#  {'count': 2, 'title': 'The Bandit', 'year': 1946},
#  {'count': 2, 'title': 'Charms Zwischenfèlle', 'year': 1996},
#  {'count': 2, 'title': 'No', 'year': 2012},
#  {'count': 2, 'title': 'Lady in the Water', 'year': 2006},
#  {'count': 2, 'title': 'The Things of Life', 'year': 1970},
#  {'count': 2,
#   'title': 'Genius Within: The Inner Life of Glenn Gould',
#   'year': 2009},
#  {'count': 2, 'title': 'Devdas', 'year': 2002},
#  {'count': 2, 'title': "A Birder's Guide to Everything", 'year': 2013},
#  {'count': 2, 'title': 'American Promise', 'year': 2013},
#  {'count': 2, 'title': 'Wreck-It Ralph', 'year': 2012},
#  {'count': 2, 'title': 'The Kiss', 'year': 1988},
#  {'count': 2, 'title': 'Circle', 'year': 2015},
#  {'count': 2, 'title': "I'm the One You Want", 'year': 2014},
#  {'count': 2, 'title': "We Don't Care About Music Anyway", 'year': 2009},
#  {'count': 2, 'title': 'The Caretakers', 'year': 1963},
#  {'count': 2, 'title': 'Above and Below', 'year': 2015},
#  {'count': 2, 'title': '40 Pounds of Trouble', 'year': 1962},
#  {'count': 2, 'title': 'Somewhere Under the Broad Sky', 'year': 1954},
#  {'count': 2, 'title': "The Butterfly's Dream", 'year': 2013},
#  {'count': 2, 'title': 'Spice World', 'year': 1997},
#  {'count': 2, 'title': 'The War', 'year': 2007},
#  {'count': 2, 'title': 'Im Sommer wohnt er unten', 'year': 2015},
#  {'count': 2, 'title': "Everybody's Got Somebody... Not Me", 'year': 2012},
#  {'count': 2, 'title': 'The Catered Affair', 'year': 1956},
#  {'count': 2, 'title': 'Drive Thru', 'year': 2007},
#  {'count': 2, 'title': 'Powder', 'year': 1995},
#  {'count': 2, 'title': 'Two Deaths', 'year': 1995},
#  {'count': 2, 'title': 'Bungee Jumping of Their Own', 'year': 2001},
#  {'count': 2, 'title': "Bill Maher... But I'm Not Wrong", 'year': 2010},
#  {'count': 2, 'title': 'Happy Ever Afters', 'year': 2009},
#  {'count': 2, 'title': '009 Re: Cyborg', 'year': 2012},
#  {'count': 2, 'title': 'Once Upon a Time in Shanghai', 'year': 2014},
#  {'count': 2, 'title': 'Tadpole', 'year': 2000},
#  {'count': 2, 'title': 'Dreamscape', 'year': 1984},
#  {'count': 2, 'title': 'Noise', 'year': 2004},
#  {'count': 2, 'title': 'El amor brujo', 'year': 1986},
#  {'count': 2, 'title': 'Decency', 'year': 2013},
#  {'count': 2, 'title': 'Wild Flowers', 'year': 2000},
#  {'count': 2, 'title': 'The Awakening', 'year': 2011},
#  {'count': 2, 'title': 'Saint Jack', 'year': 1979},
#  {'count': 2, 'title': 'Bang the Drum Slowly', 'year': 1973},
#  {'count': 2, 'title': 'The Children', 'year': 2008},
#  {'count': 2, 'title': 'Boy s tenyu', 'year': 2005},
#  {'count': 2, 'title': 'Sweetie', 'year': 1989},
#  {'count': 2, 'title': 'Pyaar Impossible!', 'year': 2010},
#  {'count': 2, 'title': 'Inside Job', 'year': 2010},
#  {'count': 2, 'title': 'Love Without Pity', 'year': 1989},
#  {'count': 2, 'title': 'Keep Your Distance', 'year': 2005},
#  {'count': 2, 'title': 'Blazing Saddles', 'year': 1974},
#  {'count': 2, 'title': 'Better Than Chocolate', 'year': 1999},
#  {'count': 2, 'title': 'One Fine Day', 'year': 1996},
#  {'count': 2, 'title': 'The Adultress', 'year': 1953},
#  {'count': 2, 'title': 'The Left Handed Gun', 'year': 1958},
#  {'count': 2, 'title': 'The Witches of Eastwick', 'year': 1987},
#  {'count': 2, 'title': 'A Little Help', 'year': 2010},
#  {'count': 2, 'title': 'Mother and Child', 'year': 2009},
#  {'count': 2, 'title': 'Il minestrone', 'year': 1981},
#  {'count': 2, 'title': 'Barefoot in the Park', 'year': 1967},
#  {'count': 2, 'title': 'Suburban Gothic', 'year': 2014},
#  {'count': 2, 'title': 'PK', 'year': 2014},
#  {'count': 2, 'title': 'Arthur Christmas', 'year': 2011},
#  {'count': 2, 'title': "You Can't Take It With You", 'year': 1938},
#  {'count': 2, 'title': 'Adult World', 'year': 2013},
#  {'count': 2, 'title': 'Appleseed Saga: Ex Machina', 'year': 2007},
#  {'count': 2, 'title': 'Raising Victor Vargas', 'year': 2002},
#  {'count': 2, 'title': 'Shining Through', 'year': 1992},
#  {'count': 2, 'title': 'Phobia 2', 'year': 2009},
#  {'count': 2, 'title': 'The Russian Novel', 'year': 2012},
#  {'count': 2, 'title': 'The Lobster', 'year': 2015},
#  {'count': 2, 'title': 'The Answer Man', 'year': 2009},
#  {'count': 2, 'title': 'Bad Words', 'year': 2013},
#  {'count': 2, 'title': 'Men Vs Women', 'year': 2010},
#  {'count': 2, 'title': 'The Delay', 'year': 2012},
#  {'count': 2, 'title': '99 francs', 'year': 2007},
#  {'count': 2, 'title': 'The Bridesmaid', 'year': 2004},
#  {'count': 2, 'title': 'Mr. Baseball', 'year': 1992},
#  {'count': 2, 'title': 'Small Apartments', 'year': 2012},
#  {'count': 2, 'title': 'La dèsenchantèe', 'year': 1990},
#  {'count': 2, 'title': 'Tear This Heart Out', 'year': 2008},
#  {'count': 2, 'title': "The Band's Visit", 'year': 2007},
#  {'count': 2, 'title': 'The River', 'year': 1984},
#  {'count': 2, 'title': 'The Pentagon Papers', 'year': 2003},
#  {'count': 2, 'title': 'Three', 'year': 1965},
#  {'count': 2, 'title': 'Cannibal Girls', 'year': 1973},
#  {'count': 2, 'title': 'Ek Thi Daayan', 'year': 2013},
#  {'count': 2, 'title': 'Lakota Woman: Siege at Wounded Knee', 'year': 1994},
#  {'count': 2, 'title': 'Creature', 'year': 1999},
#  {'count': 2, 'title': 'Terminator Genisys', 'year': 2015},
#  {'count': 2, 'title': 'Century of Birthing', 'year': 2011},
#  {'count': 2, 'title': 'Beautiful Girls', 'year': 1996},
#  {'count': 2, 'title': 'Semi-Pro', 'year': 2008},
#  {'count': 2, 'title': 'Images', 'year': 1972},
#  {'count': 2, 'title': 'The Truce', 'year': 1997},
#  {'count': 2, 'title': 'Ya ostayus', 'year': 2007},
#  {'count': 2, 'title': 'The Lucky One', 'year': 2012},
#  {'count': 2, 'title': 'El Estudiante', 'year': 2009},
#  {'count': 2, 'title': 'Miss Representation', 'year': 2011},
#  {'count': 2, 'title': "A Hard Day's Night", 'year': 1964},
#  {'count': 2, 'title': 'Oye Lucky! Lucky Oye!', 'year': 2008},
#  {'count': 2, 'title': 'Robot Jox', 'year': 1989},
#  {'count': 2, 'title': 'The Grand Maneuver', 'year': 1955},
#  {'count': 2, 'title': 'An Injury to One', 'year': 2002},
#  {'count': 2, 'title': 'Starter for 10', 'year': 2006},
#  {'count': 2, 'title': 'Bes Sehir', 'year': 2010},
#  {'count': 2, 'title': 'An Englishman in New York', 'year': 2009},
#  {'count': 2,
#   'title': 'Forklift Driver Klaus: The First Day on the Job',
#   'year': 2000},
#  {'count': 2, 'title': 'Little Children', 'year': 2006},
#  {'count': 2, 'title': 'Some Guy Who Kills People', 'year': 2011},
#  {'count': 2, 'title': 'Broken Embraces', 'year': 2009},
#  {'count': 2, 'title': '20,000 Days on Earth', 'year': 2014},
#  {'count': 2, 'title': 'Dustbin Baby', 'year': 2008},
#  {'count': 2, 'title': 'The Terror Live', 'year': 2013},
#  {'count': 2, 'title': 'Murder in Greenwich', 'year': 2002},
#  {'count': 2, 'title': 'The Brotherhood', 'year': 1968},
#  {'count': 2, 'title': 'Jack Frost', 'year': 1998},
#  {'count': 2, 'title': 'Nico and Dani', 'year': 2000},
#  {'count': 2, 'title': 'Raavan', 'year': 2010},
#  {'count': 2, 'title': 'Princess Mononoke', 'year': 1997},
#  {'count': 2, 'title': 'Topsy-Turvy', 'year': 1999},
#  {'count': 2, 'title': "Girls Can't Swim", 'year': 2000},
#  {'count': 2, 'title': "Jacob's Ladder", 'year': 1990},
#  {'count': 2, 'title': 'S#x Acts', 'year': 2012},
#  {'count': 2, 'title': 'Star Runner', 'year': 2003},
#  {'count': 2, 'title': 'Ted', 'year': 2012},
#  {'count': 2, 'title': 'Enough', 'year': 2002},
#  {'count': 2, 'title': 'Pitkè kuuma kesè', 'year': 1999},
#  {'count': 2, 'title': 'What Happened Was...', 'year': 1994},
#  {'count': 2, 'title': 'Kung Fury', 'year': 2015},
#  {'count': 2, 'title': 'Grizzly Falls', 'year': 1999},
#  {'count': 2, 'title': 'Jack Goes Boating', 'year': 2010},
#  {'count': 2, 'title': 'One Eight Seven', 'year': 1997},
#  {'count': 2, 'title': 'Miss Julie', 'year': 1999},
#  {'count': 2, 'title': 'Scattered Cloud', 'year': 2011},
#  {'count': 2, 'title': 'Will Success Spoil Rock Hunter?', 'year': 1957},
#  {'count': 2, 'title': 'Rich Kids', 'year': 1979},
#  {'count': 2, 'title': 'De vlaschaard', 'year': 1985},
#  {'count': 2, 'title': 'Love Is My Profession', 'year': 1958},
#  {'count': 2,
#   'title': 'Joseph and the Amazing Technicolor Dreamcoat',
#   'year': 1999},
#  {'count': 2, 'title': 'Blind Date', 'year': 1987},
#  {'count': 2, 'title': 'The Kentuckian', 'year': 1955},
#  {'count': 2, 'title': 'Destino', 'year': 2003},
#  {'count': 2, 'title': 'The Falling', 'year': 2014},
#  {'count': 2, 'title': 'Ronin', 'year': 1998},
#  {'count': 2, 'title': 'Mystery Road', 'year': 2013},
#  {'count': 2, 'title': 'Big Game', 'year': 2014},
#  {'count': 2, 'title': 'Titanica', 'year': 1995},
#  {'count': 2, 'title': 'Undertow', 'year': 2004},
#  {'count': 2, 'title': 'The Last of the High Kings', 'year': 1996},
#  {'count': 2, 'title': 'First Flight', 'year': 2006},
#  {'count': 2, 'title': 'Local Color', 'year': 2006},
#  {'count': 2, 'title': 'The Noble Family', 'year': 2013},
#  {'count': 2, 'title': 'Pieces of Dreams', 'year': 1970},
#  {'count': 2, 'title': 'Morgen', 'year': 2010},
#  {'count': 2, 'title': 'Jitters', 'year': 2010},
#  {'count': 2, 'title': 'The Adderall Diaries', 'year': 2015},
#  {'count': 2, 'title': 'Thorne: Sleepyhead', 'year': 2010},
#  {'count': 2, 'title': "Nobody's Daughter Haewon", 'year': 2013},
#  {'count': 2, 'title': 'Latter Days', 'year': 2003},
#  {'count': 2, 'title': '4 Minutes', 'year': 2006},
#  {'count': 2, 'title': 'Truly Human', 'year': 2001},
#  {'count': 2, 'title': 'Where the Green Ants Dream', 'year': 1984},
#  {'count': 2, 'title': 'The Paper Brigade', 'year': 1996},
#  {'count': 2, 'title': 'Carrie', 'year': 2013},
#  {'count': 2, 'title': 'Saving Face', 'year': 2004},
#  {'count': 2, 'title': 'Drowsiness', 'year': 2008},
#  {'count': 2, 'title': 'Lyubov 2 Morkov', 'year': 2008},
#  {'count': 2, 'title': "Lord's Lantern in Budapest", 'year': 1999},
#  {'count': 2, 'title': 'EuroTrip', 'year': 2004},
#  {'count': 2, 'title': 'Rozygrysh', 'year': 2008},
#  {'count': 2, 'title': "Cutter's Way", 'year': 1981},
#  {'count': 2, 'title': 'Freeway', 'year': 1996},
#  {'count': 2, 'title': 'Great Balls of Fire!', 'year': 1989},
#  {'count': 2, 'title': 'Priceless', 'year': 2006},
#  {'count': 2, 'title': 'Midnight Express', 'year': 1978},
#  {'count': 2, 'title': 'Eating', 'year': 1990},
#  {'count': 2, 'title': 'S.O.B.', 'year': 1981},
#  {'count': 2, 'title': 'Secret Smile', 'year': 2005},
#  {'count': 2, 'title': 'Princess Arete', 'year': 2001},
#  {'count': 2, 'title': 'Little Hope Was Arson', 'year': 2013},
#  {'count': 2, 'title': 'Percy Jackson: Sea of Monsters', 'year': 2013},
#  {'count': 2, 'title': "His Wife's Diary", 'year': 2000},
#  {'count': 2, 'title': 'The Little Prince', 'year': 1974},
#  {'count': 2, 'title': 'Beetle Queen Conquers Tokyo', 'year': 2009},
#  {'count': 2, 'title': 'Gidget', 'year': 1959},
#  {'count': 2, 'title': 'Helter Skelter', 'year': 2012},
#  {'count': 2, 'title': 'Yankee Doodle Dandy', 'year': 1942},
#  {'count': 2, 'title': 'Cinderfella', 'year': 1960},
#  {'count': 2, 'title': 'Time Stood Still', 'year': 1959},
#  {'count': 2, 'title': 'Flirting with Disaster', 'year': 1996},
#  {'count': 2, 'title': 'The Blue Umbrella', 'year': 2013},
#  {'count': 2, 'title': 'Catfish in Black Bean Sauce', 'year': 1999},
#  {'count': 2, 'title': 'Goon', 'year': 2011},
#  {'count': 2, 'title': 'Disaster Movie', 'year': 2008},
#  {'count': 2, 'title': 'Ghosts of the Abyss', 'year': 2003},
#  {'count': 2, 'title': 'The Deluge', 'year': 1974},
#  {'count': 2, 'title': 'Alfie', 'year': 1966},
#  {'count': 2, 'title': 'Deadly Voyage', 'year': 1996},
#  {'count': 2, 'title': 'The Santa Clause 2', 'year': 2002},
#  {'count': 2, 'title': 'Boogie', 'year': 2009},
#  {'count': 2, 'title': 'Khottabych', 'year': 2006},
#  {'count': 2, 'title': 'My Bloody Valentine', 'year': 2009},
#  {'count': 2, 'title': 'Ruhr', 'year': 2009},
#  {'count': 2, 'title': 'My Sweet Little Village', 'year': 1985},
#  {'count': 2, 'title': 'Bestseller', 'year': 2010},
#  {'count': 2, 'title': "The Tiger's Tail", 'year': 2006},
#  {'count': 2, 'title': 'Shiloh', 'year': 1996},
#  {'count': 2, 'title': 'Ghost World', 'year': 2001},
#  {'count': 2, 'title': 'Teenage', 'year': 2013},
#  {'count': 2, 'title': 'Cheap Smokes', 'year': 2000},
#  {'count': 2, 'title': 'To Rome with Love', 'year': 2012},
#  {'count': 2, 'title': 'Heaven', 'year': 1998},
#  {'count': 2, 'title': 'Hatchet II', 'year': 2010},
#  {'count': 2, 'title': 'Just Like a Woman', 'year': 2012},
#  {'count': 2, 'title': 'Six Weeks', 'year': 1982},
#  {'count': 2, 'title': 'White Lion', 'year': 2010},
#  {'count': 2, 'title': 'Les convoyeurs attendent', 'year': 1999},
#  {'count': 2, 'title': 'Justice League: Doom', 'year': 2012},
#  {'count': 2, 'title': 'Bonjour Monsieur Shlomi', 'year': 2003},
#  {'count': 2, 'title': 'PiraMMMida', 'year': 2011},
#  {'count': 2, 'title': 'Battlefield Earth', 'year': 2000},
#  {'count': 2, 'title': 'Toad Road', 'year': 2012},
#  {'count': 2, 'title': 'La escopeta nacional', 'year': 1978},
#  {'count': 2, 'title': "Forever's End", 'year': 2013},
#  {'count': 2, 'title': 'Hit & Miss', 'year': '2012è'},
#  {'count': 2, 'title': 'The Giants', 'year': 2011},
#  {'count': 2, 'title': 'Common Threads: Stories from the Quilt', 'year': 1989},
#  {'count': 2, 'title': 'Room for One More', 'year': 1952},
#  {'count': 2,
#   'title': 'The Crimson Wing: Mystery of the Flamingos',
#   'year': 2008},
#  {'count': 2, 'title': 'Tamala 2010: A Punk Cat in Space', 'year': 2002},
#  {'count': 2, 'title': 'The Mangler', 'year': 1995},
#  {'count': 2, 'title': 'Detention', 'year': 2003},
#  {'count': 2, 'title': 'The Last Sentence', 'year': 2012},
#  {'count': 2, 'title': 'R.S.V.P.', 'year': 2002},
#  {'count': 2, 'title': "Refugee All Stars, Sierra Leone's", 'year': 2005},
#  {'count': 2, 'title': 'Lucky Luke and the Daltons', 'year': 2004},
#  {'count': 2, 'title': 'Like You Know It All', 'year': 2009},
#  {'count': 2, 'title': 'Source Code', 'year': 2011},
#  {'count': 2, 'title': 'Miss Minoes', 'year': 2001},
#  {'count': 2, 'title': 'I Am Maria', 'year': 1979},
#  {'count': 2,
#   'title': 'Temptation: Confessions of a Marriage Counselor',
#   'year': 2013},
#  {'count': 2, 'title': 'Elliot Loves', 'year': 2012},
#  {'count': 2, 'title': 'Sabotage', 'year': 2014},
#  {'count': 2, 'title': 'Crazy for Christmas', 'year': 2005},
#  {'count': 2, 'title': 'City Heat', 'year': 1984},
#  {'count': 2, 'title': 'Sorority Boys', 'year': 2002},
#  {'count': 2, 'title': 'Men in the City 2', 'year': 2011},
#  {'count': 2, 'title': 'Red Riding Hood', 'year': 2011},
#  {'count': 2, 'title': 'Look', 'year': 2007},
#  {'count': 2, 'title': 'The Princess and the Warrior', 'year': 2000},
#  {'count': 2, 'title': 'Crazy', 'year': 2000},
#  {'count': 2, 'title': 'Rosvo Roope', 'year': 1949},
#  {'count': 2, 'title': 'Niezwykla podrèz Baltazara Kobera', 'year': 1988},
#  {'count': 2, 'title': 'The Whole Ten Yards', 'year': 2004},
#  {'count': 2, 'title': 'Two Weeks Notice', 'year': 2002},
#  {'count': 2, 'title': 'A City of Sadness', 'year': 1989},
#  {'count': 2, 'title': 'The Forgotten', 'year': 2004},
#  {'count': 2, 'title': 'Night Must Fall', 'year': 1937},
#  {'count': 2, 'title': "Charlotte's Web", 'year': 2006},
#  {'count': 2, 'title': 'A Life Less Ordinary', 'year': 1997},
#  {'count': 2, 'title': 'Pierrepoint: The Last Hangman', 'year': 2005},
#  {'count': 2, 'title': "I'm Still Here", 'year': 2010},
#  {'count': 2, 'title': 'Wedding Chest', 'year': 2005},
#  {'count': 2, 'title': 'The Union', 'year': 2011},
#  {'count': 2, 'title': 'Mujhse Dosti Karoge!', 'year': 2002},
#  {'count': 2, 'title': 'Tooth Fairy', 'year': 2010},
#  {'count': 2, 'title': 'The Player', 'year': 1992},
#  {'count': 2, 'title': 'Some Girl', 'year': 1998},
#  {'count': 2, 'title': 'Jeanne la Pucelle II - Les prisons', 'year': 1994},
#  {'count': 2, 'title': 'Pride', 'year': 2014},
#  {'count': 2, 'title': 'Lucky Luke', 'year': 1991},
#  {'count': 2, 'title': 'Jekyll & Hyde', 'year': 1990},
#  {'count': 2, 'title': 'Our Song', 'year': 2000},
#  {'count': 2, 'title': 'Disclosure', 'year': 1994},
#  {'count': 2, 'title': 'The End of the Affair', 'year': 1955},
#  {'count': 2, 'title': 'Our Town', 'year': 2007},
#  {'count': 2, 'title': 'Poppy Shakespeare', 'year': 2008},
#  {'count': 2, 'title': 'Mickybo and Me', 'year': 2004},
#  {'count': 2, 'title': 'The Illusionist', 'year': 2006},
#  {'count': 2, 'title': 'Saheb Biwi Aur Gangster', 'year': 2011},
#  {'count': 2, 'title': 'Fresh Bait', 'year': 1995},
#  {'count': 2, 'title': 'Testament', 'year': 1983},
#  {'count': 2, 'title': "Tuya's Marriage", 'year': 2006},
#  {'count': 2, 'title': 'West', 'year': 2013},
#  {'count': 2, 'title': 'Galaxy Express 999', 'year': 1979},
#  {'count': 2, 'title': 'The Great Santini', 'year': 1979},
#  {'count': 2, 'title': 'It Rains in My Village', 'year': 1968},
#  {'count': 2, 'title': 'Made in America', 'year': 2013},
#  {'count': 2, 'title': 'Amiche da morire', 'year': 2013},
#  {'count': 2, 'title': 'The Count of Monte Cristo', 'year': 1954},
#  {'count': 2, 'title': 'Second Skin', 'year': 1999},
#  {'count': 2, 'title': 'Afterwards', 'year': 2008},
#  {'count': 2, 'title': 'Quo Vadis, Baby?', 'year': 2005},
#  {'count': 2, 'title': 'Funeral March', 'year': 2001},
#  {'count': 2, 'title': 'Looking for Eric', 'year': 2009},
#  {'count': 2, 'title': 'Carriers', 'year': 2009},
#  {'count': 2, 'title': 'Sleeping with the Fishes', 'year': 2013},
#  {'count': 2,
#   'title': 'B-Movie: Lust & Sound in West-Berlin 1979-1989',
#   'year': 2015},
#  {'count': 2, 'title': 'The Rain People', 'year': 1969},
#  {'count': 2, 'title': 'The Dentist', 'year': 1996},
#  {'count': 2, 'title': 'Hachi-ko', 'year': 1987},
#  {'count': 2, 'title': 'White Bird in a Blizzard', 'year': 2014},
#  {'count': 2, 'title': 'Messi', 'year': 2014},
#  {'count': 2, 'title': 'Road House', 'year': 1989},
#  {'count': 2, 'title': 'Echoes of the Rainbow', 'year': 2010},
#  {'count': 2, 'title': 'Girl Fight', 'year': 2011},
#  {'count': 2, 'title': 'Sword Art Online Extra Edition', 'year': 2013},
#  {'count': 2, 'title': 'Crashing Las Vegas', 'year': 1956},
#  {'count': 2, 'title': 'The Stranger', 'year': 1991},
#  {'count': 2, 'title': 'Fort Tilden', 'year': 2014},
#  {'count': 2, 'title': 'Gold', 'year': 1974},
#  {'count': 2, 'title': 'Broken Lullaby', 'year': 1932},
#  {'count': 2, 'title': 'The Journey', 'year': 2014},
#  {'count': 2, 'title': 'Destiny', 'year': 2006},
#  {'count': 2, 'title': 'Wolf Totem', 'year': 2015},
#  {'count': 2, 'title': 'Yves Saint Laurent', 'year': 2014},
#  {'count': 2, 'title': 'Big Trouble in Little China', 'year': 1986},
#  {'count': 2, 'title': 'Butterfly', 'year': 1999},
#  {'count': 2, 'title': 'Fiorile', 'year': 1993},
#  {'count': 2, 'title': 'Julia and Julia', 'year': 1987},
#  {'count': 2, 'title': 'Beefcake', 'year': 1998},
#  {'count': 2, 'title': 'Wandering Sagittarius', 'year': 1993},
#  {'count': 2, 'title': 'Road House', 'year': 1948},
#  {'count': 2, 'title': 'Maledimiele', 'year': 2011},
#  {'count': 2, 'title': 'Lakota Woman: Siege at Wounded Knee', 'year': 1994},
#  {'count': 2, 'title': 'Bad Eggs', 'year': 2003},
#  {'count': 2, 'title': 'Patlabor 2: The Movie', 'year': 1993},
#  {'count': 2, 'title': 'Kabhi Khushi Kabhie Gham...', 'year': 2001},
#  {'count': 2, 'title': 'The Floating Castle', 'year': 2012},
#  {'count': 2, 'title': 'Out of the Blue', 'year': 2006},
#  {'count': 2, 'title': 'Lars and the Real Girl', 'year': 2007},
#  {'count': 2, 'title': "Nobody's Fool", 'year': 1994},
#  {'count': 2, 'title': "Thou Gild'st the Even", 'year': 2013},
#  {'count': 2, 'title': 'Ju-on: The Grudge', 'year': 2002},
#  {'count': 2, 'title': 'Pathfinder', 'year': 2007},
#  {'count': 2, 'title': 'The Boxcar Children', 'year': 2014},
#  {'count': 2, 'title': 'Due Date', 'year': 2010},
#  {'count': 2, 'title': 'Furry Vengeance', 'year': 2010},
#  {'count': 2, 'title': 'Bitva za Sevastopol', 'year': 2015},
#  {'count': 2, 'title': 'Charly', 'year': 1968},
#  {'count': 2, 'title': 'The Settlement', 'year': 2002},
#  {'count': 2, 'title': 'Sissi: The Fateful Years of an Empress', 'year': 1957},
#  {'count': 2, 'title': 'Bodysong', 'year': 2003},
#  {'count': 2, 'title': 'The Love Guru', 'year': 2008},
#  {'count': 2, 'title': 'Torque', 'year': 2004},
#  {'count': 2, 'title': 'Shakthi: The Power', 'year': 2002},
#  {'count': 2, 'title': 'Slaughterhouse-Five', 'year': 1972},
#  {'count': 2, 'title': 'All the Wilderness', 'year': 2014},
#  {'count': 2, 'title': 'The Time Machine', 'year': 2002},
#  {'count': 2, 'title': 'Daybreakers', 'year': 2009},
#  {'count': 2, 'title': 'OT: Our Town', 'year': 2002},
#  {'count': 2, 'title': 'The Runway', 'year': 2010},
#  {'count': 2, 'title': 'Visitor Q', 'year': 2001},
#  {'count': 2, 'title': 'Den ofrivillige golfaren', 'year': 1991},
#  {'count': 2, 'title': 'Mortadelo & Filemon: The Big Adventure', 'year': 2003},
#  {'count': 2, 'title': 'Sarkar Raj', 'year': 2008},
#  {'count': 2, 'title': 'The Lost Bladesman', 'year': 2011},
#  {'count': 2, 'title': 'The Moon in the Gutter', 'year': 1983},
#  {'count': 2, 'title': 'Marine Battleground', 'year': 1963},
#  {'count': 2, 'title': "What Doesn't Kill You", 'year': 2008},
#  {'count': 2,
#   'title': 'We Steal Secrets: The Story of WikiLeaks',
#   'year': 2013},
#  {'count': 2, 'title': 'Heaven and Earth', 'year': 1990},
#  {'count': 2, 'title': 'Sorry for the Disturbance', 'year': 2008},
#  {'count': 2, 'title': 'Faintheart', 'year': 2008},
#  {'count': 2, 'title': 'The Elusive Corporal', 'year': 1962},
#  {'count': 2, 'title': 'Joe Hill', 'year': 1971},
#  {'count': 2, 'title': 'End of the Spear', 'year': 2005},
#  {'count': 2,
#   'title': 'The Land Before Time XIII: The Wisdom of Friends',
#   'year': 2007},
#  {'count': 2, 'title': 'Thirteen', 'year': 2003},
#  {'count': 2, 'title': 'The Signal', 'year': 2007},
#  {'count': 2, 'title': 'Muzi bez krèdel', 'year': 1946},
#  {'count': 2, 'title': 'Kafka', 'year': 1991},
#  {'count': 2,
#   'title': 'The End of Suburbia: Oil Depletion and the Collapse of the American Dream',
#   'year': 2004},
#  {'count': 2, 'title': 'The Christmas Party', 'year': 2009},
#  {'count': 2, 'title': "Marie's Story", 'year': 2014},
#  {'count': 2, 'title': 'The Naked and the Dead', 'year': 1958},
#  {'count': 2, 'title': 'The Angry Silence', 'year': 1960},
#  {'count': 2, 'title': 'Xala', 'year': 1975},
#  {'count': 2, 'title': 'In the Name of the Pope King', 'year': 1977},
#  {'count': 2, 'title': 'Unbreakable', 'year': 2000},
#  {'count': 2, 'title': 'Triumph Over Violence', 'year': 1965},
#  {'count': 2, 'title': 'Shock Head Soul', 'year': 2011},
#  {'count': 2, 'title': 'Urbania', 'year': 2000},
#  {'count': 2, 'title': 'The Infinite Man', 'year': 2014},
#  {'count': 2, 'title': 'Bright Lights, Big City', 'year': 1988},
#  {'count': 2, 'title': 'Thor', 'year': 2011},
#  {'count': 2, 'title': 'The Nude Bomb', 'year': 1980},
#  {'count': 2, 'title': 'Faithless', 'year': 2000},
#  {'count': 2, 'title': 'Blood River', 'year': 1967},
#  {'count': 2, 'title': 'Storage 24', 'year': 2012},
#  {'count': 2, 'title': 'Downfall', 'year': 2004},
#  {'count': 2, 'title': 'Isadora', 'year': 1968},
#  {'count': 2, 'title': 'Red Ants', 'year': 2007},
#  {'count': 2, 'title': "A Knight's Tale", 'year': 2001},
#  {'count': 2, 'title': 'Goyokin', 'year': 1969},
#  {'count': 2, 'title': 'Sacrifice', 'year': 2010},
#  {'count': 2, 'title': 'Bewitched', 'year': 2005},
#  {'count': 2, 'title': 'The Tough Ones', 'year': 1999},
#  {'count': 2, 'title': 'The Breach', 'year': 1970},
#  {'count': 2, 'title': 'The Policeman', 'year': 1971},
#  {'count': 2, 'title': 'The Bachelor', 'year': 1955},
#  {'count': 2, 'title': "The Devil's Backbone", 'year': 2001},
#  {'count': 2,
#   'title': 'Mermaid Chronicles Part 1: She Creature',
#   'year': 2001},
#  {'count': 2, 'title': 'The Quiet Family', 'year': 1998},
#  {'count': 2, 'title': 'Mississippi Burning', 'year': 1988},
#  {'count': 2, 'title': 'A Slipping-Down Life', 'year': 1999},
#  {'count': 2, 'title': 'And While We Were Here', 'year': 2012},
#  {'count': 2, 'title': 'The First Wives Club', 'year': 1996},
#  {'count': 2, 'title': 'Downeast', 'year': 2012},
#  {'count': 2,
#   'title': 'Thirty Two Short Films About Glenn Gould',
#   'year': 1993},
#  {'count': 2, 'title': 'Cubeè: Hypercube', 'year': 2002},
#  {'count': 2, 'title': "Child's Play 2", 'year': 1990},
#  {'count': 2, 'title': "I Don't Buy Kisses Anymore", 'year': 1992},
#  {'count': 2, 'title': "Mary Shelley's Frankenstein", 'year': 1994},
#  {'count': 2, 'title': 'Dirty Pictures', 'year': 2000},
#  {'count': 2, 'title': 'No Good Deed', 'year': 2002},
#  {'count': 2, 'title': 'Approaching the Elephant', 'year': 2014},
#  {'count': 2, 'title': 'Firestorm', 'year': 2013},
#  {'count': 2, 'title': 'Cannonball Fever', 'year': 1989},
#  {'count': 2, 'title': 'Ride Along', 'year': 2014},
#  {'count': 2, 'title': 'Pulse', 'year': 2001},
#  {'count': 2, 'title': 'Black Souls', 'year': 2014},
#  {'count': 2, 'title': 'Sebbe', 'year': 2010},
#  {'count': 2, 'title': 'Barocco', 'year': 1976},
#  {'count': 2, 'title': 'C.H.U.D.', 'year': 1984},
#  {'count': 2, 'title': 'Love in the Time of Money', 'year': 2002},
#  {'count': 2, 'title': 'Unforgiven', 'year': 1992},
#  {'count': 2, 'title': 'Enamorada', 'year': 1946},
#  {'count': 2, 'title': 'The Painting', 'year': 2011},
#  {'count': 2, 'title': 'The Mugger', 'year': 2007},
#  {'count': 2, 'title': 'Melissa P.', 'year': 2005},
#  {'count': 2, 'title': 'Species III', 'year': 2004},
#  {'count': 2, 'title': 'Family Secrets', 'year': 2001},
#  {'count': 2, 'title': 'Bangkok Hilton', 'year': 1989},
#  {'count': 2, 'title': 'We Are Marshall', 'year': 2006},
#  {'count': 2, 'title': 'The Strong Man', 'year': 1926},
#  {'count': 2, 'title': 'The Siege', 'year': 1998},
#  {'count': 2, 'title': 'The Amati Girls', 'year': 2000},
#  {'count': 2, 'title': 'StarStruck', 'year': 2010},
#  {'count': 2, 'title': 'The Bridge', 'year': 1999},
#  {'count': 2, 'title': "Fanie Fourie's Lobola", 'year': 2013},
#  {'count': 2, 'title': 'Ride a Crooked Trail', 'year': 1958},
#  {'count': 2, 'title': 'No Path Through Fire', 'year': 1968},
#  {'count': 2, 'title': 'We Are Young. We Are Strong.', 'year': 2014},
#  {'count': 2, 'title': "Porky's", 'year': 1981},
#  {'count': 2, 'title': 'Erebus: Into the Unknown', 'year': 2014},
#  {'count': 2, 'title': 'Hiroshima', 'year': 2005},
#  {'count': 2, 'title': "Avellaneda's Moon", 'year': 2004},
#  {'count': 2, 'title': 'Eye in the Sky', 'year': 2007},
#  {'count': 2, 'title': 'Redacted', 'year': 2007},
#  {'count': 2, 'title': 'Polycarp', 'year': 2015},
#  {'count': 2, 'title': 'Sammy and Me', 'year': 2002},
#  {'count': 2, 'title': 'Dance, Girl, Dance', 'year': 1940},
#  {'count': 2, 'title': 'Jesus Is a Palestinian', 'year': 1999},
#  {'count': 2, 'title': 'Don', 'year': 1978},
#  {'count': 2, 'title': 'The Jew in the Lotus', 'year': 1998},
#  {'count': 2, 'title': 'My Life Without Me', 'year': 2003},
#  {'count': 2, 'title': 'Day & Night', 'year': 2010},
#  {'count': 2, 'title': 'Shotgun Stories', 'year': 2007},
#  {'count': 2, 'title': 'Newsfront', 'year': 1978},
#  {'count': 2, 'title': 'Motorway', 'year': 2012},
#  {'count': 2, 'title': 'Cattle Annie and Little Britches', 'year': 1981},
#  {'count': 2,
#   'title': 'Breaking the Surface: The Greg Louganis Story',
#   'year': 1997},
#  {'count': 2, 'title': 'Snakes and Earrings', 'year': 2008},
#  {'count': 2, 'title': 'Mondo', 'year': 1995},
#  {'count': 2, 'title': 'Orlando', 'year': 1992},
#  {'count': 2, 'title': 'My Tomorrow', 'year': 2011},
#  {'count': 2, 'title': 'Twins', 'year': 1988},
#  {'count': 2, 'title': 'The Unfaithful Wife', 'year': 1969},
#  {'count': 2, 'title': 'Parenthood', 'year': 1989},
#  {'count': 2, 'title': 'Class Action', 'year': 1991},
#  {'count': 2, 'title': 'The King of the Street Cleaners', 'year': 1977},
#  {'count': 2, 'title': 'Om Shanti Om', 'year': 2007},
#  {'count': 2, 'title': 'Ivy', 'year': 2015},
#  {'count': 2, 'title': 'The Wooden Bridge', 'year': 2012},
#  {'count': 2, 'title': 'Nowhere Boy', 'year': 2009},
#  {'count': 2, 'title': 'Me and Morrison', 'year': 2001},
#  {'count': 2, 'title': 'Delicacy', 'year': 2011},
#  {'count': 2, 'title': 'Dancemaker', 'year': 1998},
#  {'count': 2, 'title': "Dave Chappelle: For What It's Worth", 'year': 2004},
#  {'count': 2,
#   'title': 'The Wild and Wonderful Whites of West Virginia',
#   'year': 2009},
#  {'count': 2, 'title': 'Nomad: The Warrior', 'year': 2005},
#  {'count': 2, 'title': 'Road, Movie', 'year': 2009},
#  {'count': 2, 'title': 'La strega in amore', 'year': 1966},
#  {'count': 2, 'title': 'Death of a Salesman', 'year': 1985},
#  {'count': 2, 'title': 'End Game', 'year': 2006},
#  {'count': 2, 'title': 'The Homesman', 'year': 2014},
#  {'count': 2, 'title': 'Rude Boy', 'year': 1980},
#  {'count': 2, 'title': 'Between the Lines', 'year': 1977},
#  {'count': 2, 'title': 'Ghulam', 'year': 1998},
#  {'count': 2, 'title': 'Boys', 'year': 1977},
#  {'count': 2, 'title': 'Suspect X', 'year': 2008},
#  {'count': 2, 'title': 'Mrs Dalloway', 'year': 1997},
#  {'count': 2, 'title': 'Auk Nr. 8', 'year': 2010},
#  {'count': 2, 'title': 'The House on Carroll Street', 'year': 1988},
#  {'count': 2, 'title': 'Someone to Watch Over Me', 'year': 1987},
#  {'count': 2, 'title': 'Sweet Evil', 'year': 2010},
#  {'count': 2, 'title': 'Black Mask', 'year': 1996},
#  {'count': 2, 'title': 'Beautiful Creatures', 'year': 2013},
#  {'count': 2, 'title': 'The Out of Towners', 'year': 1970},
#  {'count': 2, 'title': 'Vitus', 'year': 2006},
#  {'count': 2, 'title': 'Oktober November', 'year': 2013},
#  {'count': 2, 'title': 'Fatso', 'year': 1980},
#  {'count': 2, 'title': "Jodorowsky's Dune", 'year': 2013},
#  {'count': 2, 'title': 'Transistor Love Story', 'year': 2001},
#  {'count': 2, 'title': 'Trial', 'year': 1955},
#  {'count': 2, 'title': 'Three Colors: Blue', 'year': 1993},
#  {'count': 2, 'title': 'Knallharte Jungs', 'year': 2002},
#  {'count': 2, 'title': 'What About Bob?', 'year': 1991},
#  {'count': 2, 'title': 'Fear No Evil', 'year': 1981},
#  {'count': 2, 'title': 'The Imitation Game', 'year': 2014},
#  {'count': 2, 'title': 'Annaluise & Anton', 'year': 1999},
#  {'count': 2, 'title': 'Soul Boys of the Western World', 'year': 2014},
#  {'count': 2, 'title': 'Two for the Seesaw', 'year': 1962},
#  {'count': 2, 'title': 'Scent of a Woman', 'year': 1992},
#  {'count': 2, 'title': 'Noce blanche', 'year': 1989},
#  {'count': 2, 'title': 'Motherhood', 'year': 2009},
#  {'count': 2, 'title': 'Muppets Most Wanted', 'year': 2014},
#  {'count': 2, 'title': 'Spontaneous Combustion', 'year': 1990},
#  {'count': 2, 'title': 'The Earth Is a Sinful Song', 'year': 1973},
#  {'count': 2, 'title': 'Oklahoma Crude', 'year': 1973},
#  {'count': 2, 'title': 'Running Scared', 'year': 2006},
#  {'count': 2, 'title': 'Oxygen', 'year': 1999},
#  {'count': 2, 'title': 'Baggage Claim', 'year': 2013},
#  {'count': 2, 'title': 'Little Girl', 'year': 2009},
#  {'count': 2, 'title': 'Hawaii, Oslo', 'year': 2004},
#  {'count': 2, 'title': 'Johnny Handsome', 'year': 1989},
#  {'count': 2, 'title': 'Blackrock', 'year': 1997},
#  {'count': 2, 'title': 'A House Built on Water', 'year': 2003},
#  {'count': 2, 'title': 'Hacking Democracy', 'year': 2006},
#  {'count': 2, 'title': 'The Carey Treatment', 'year': 1972},
#  {'count': 2, 'title': 'The Ogre of Athens', 'year': 1956},
#  {'count': 2, 'title': 'Sue', 'year': 1997},
#  {'count': 2, 'title': 'Goodfellas', 'year': 1990},
#  {'count': 2, 'title': "Say It Isn't So", 'year': 2001},
#  {'count': 2, 'title': 'The Cruise', 'year': 1998},
#  {'count': 2, 'title': 'Miracle', 'year': 2004},
#  {'count': 2, 'title': 'Hitman Hart: Wrestling with Shadows', 'year': 1998},
#  {'count': 2, 'title': 'Animal Factory', 'year': 2000},
#  {'count': 2, 'title': 'Asfalttilampaat', 'year': 1968},
#  {'count': 2,
#   'title': "Marilyn Hotchkiss' Ballroom Dancing & Charm School",
#   'year': 2005},
#  {'count': 2, 'title': 'Police Story', 'year': 1985},
#  {'count': 2, 'title': 'The Clone Returns Home', 'year': 2008},
#  {'count': 2, 'title': 'Islander', 'year': 2007},
#  {'count': 2, 'title': 'Flashdance', 'year': 1983},
#  {'count': 2, 'title': 'Monica Z', 'year': 2013},
#  {'count': 2, 'title': 'Yesterday Was a Lie', 'year': 2008},
#  {'count': 2, 'title': 'If I Were You 2', 'year': 2009},
#  {'count': 2, 'title': "Patrick's Day", 'year': 2014},
#  {'count': 2, 'title': 'Hitman Hart: Wrestling with Shadows', 'year': 1998},
#  {'count': 2, 'title': 'Venus', 'year': 2006},
#  {'count': 2, 'title': 'White Noise 2: The Light', 'year': 2007},
#  {'count': 2, 'title': 'The House of Small Cubes', 'year': 2008},
#  {'count': 2, 'title': 'The Vanishing Prairie', 'year': 1954},
#  {'count': 2, 'title': 'Die Hard 2', 'year': 1990},
#  {'count': 2, 'title': 'Year of the Devil', 'year': 2002},
#  {'count': 2, 'title': 'Boy A', 'year': 2007},
#  {'count': 2, 'title': 'Stopped on Track', 'year': 2011},
#  {'count': 2, 'title': 'Exit Wounds', 'year': 2001},
#  {'count': 2, 'title': 'Come Undone', 'year': 2000},
#  {'count': 2, 'title': 'Doctor at Sea', 'year': 1955},
#  {'count': 2, 'title': 'Short Circuit 2', 'year': 1988},
#  {'count': 2, 'title': 'Godzilla 1985', 'year': 1984},
#  {'count': 2, 'title': 'The Stepfather', 'year': 1987},
#  {'count': 2, 'title': 'Love in the Afternoon', 'year': 1957},
#  {'count': 2, 'title': 'La viaccia', 'year': 1961},
#  {'count': 2, 'title': 'Locke', 'year': 2013},
#  {'count': 2, 'title': 'Never Met Picasso', 'year': 1996},
#  {'count': 2, 'title': 'Autohystoria', 'year': 2007},
#  {'count': 2, 'title': 'Talk Radio', 'year': 1988},
#  {'count': 2, 'title': '4 Elements', 'year': 2006},
#  {'count': 2, 'title': 'Life, Autumn', 'year': 1999},
#  {'count': 2, 'title': 'The Untouchables', 'year': 1987},
#  {'count': 2, 'title': 'Hammer & Tickle', 'year': 2006},
#  {'count': 2, 'title': 'Tuesdays with Morrie', 'year': 1999},
#  {'count': 2, 'title': 'Glasblèsarns barn', 'year': 1998},
#  {'count': 2, 'title': 'The Unknown Soldier', 'year': 2006},
#  {'count': 2, 'title': 'Zindagi Na Milegi Dobara', 'year': 2011},
#  {'count': 2, 'title': 'Choking Man', 'year': 2006},
#  {'count': 2, 'title': 'Hotel Swooni', 'year': 2011},
#  {'count': 2, 'title': 'Run, Simon, Run', 'year': 1970},
#  ...]

# %% [markdown]
# #### Задача 2.2 — **1 балл**

# %% [markdown]
# Используя данные, полученные в задаче 2.1, выведите на экран столбчатую диаграмму, показывающую топ-20 наиболее комментируемых фильмов. По оси ординат выведите названия этих фильмов (подписи разместите слева диаграммы), по оси абсцисс — количество комментариев.
#
# Для решения задачи можно использовать любую библиотеку, например Seaborn или Matplotlib.

# %%
# Создаем списки названий фильмов и количества комментариев
titles = [d['title'] for d in data[:20]]
counts = [d['count'] for d in data[:20]]

# Строим столбчатый график
plt.figure(figsize=(10, 8))
plt.barh(titles, counts, color='skyblue')
plt.xlabel('Number of Comments')
plt.ylabel('Movie Title')
plt.title('Top 20 Most Commented Movies')
plt.gca().invert_yaxis()
plt.show()
